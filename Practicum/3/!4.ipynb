# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
import joblib
import neat

# %%
df_small = pd.read_csv('dataset_1.csv')
df_large = pd.read_csv('dataset_12.csv')

figure_dict = {'circle': 0, 'rectangle': 1}
color_dict = {'red': 0, 'blue': 1, 'green': 2, 'yellow': 3}

df_small['figure1'] = df_small['figure1'].map(figure_dict)
df_small['figure2'] = df_small['figure2'].map(figure_dict)
df_large['figure1'] = df_large['figure1'].map(figure_dict)
df_large['figure2'] = df_large['figure2'].map(figure_dict)
df_large['color1'] = df_large['color1'].map(color_dict)
df_large['color2'] = df_large['color2'].map(color_dict)

# %%
# Определение классов QuadTreeNode и ESHyperNEAT (без изменений)
class QuadTreeNode:
    def __init__(self, x_min, x_max, y_min, y_max, depth=0, max_depth=4):
        self.x_min, self.x_max = x_min, x_max
        self.y_min, self.y_max = y_min, y_max
        self.depth = depth
        self.max_depth = max_depth
        self.children = []
        self.neuron = None
        self.variance = None

    def split(self):
        x_mid = (self.x_min + self.x_max) / 2
        y_mid = (self.y_min + self.y_max) / 2
        self.children = [
            QuadTreeNode(self.x_min, x_mid, self.y_min, y_mid, self.depth + 1, self.max_depth),
            QuadTreeNode(x_mid, self.x_max, self.y_min, y_mid, self.depth + 1, self.max_depth),
            QuadTreeNode(self.x_min, x_mid, y_mid, self.y_max, self.depth + 1, self.max_depth),
            QuadTreeNode(x_mid, self.x_max, y_mid, self.y_max, self.depth + 1, self.max_depth)
        ]

    def place_neuron(self, x, y):
        self.neuron = (x, y)

# %%
def build_quadtree(cppn, x_min, x_max, y_min, y_max, max_depth=4, variance_threshold=0.1):
    def compute_variance(node, cppn):
        points = [
            (node.x_min, node.y_min), (node.x_max, node.y_min),
            (node.x_min, node.y_max), (node.x_max, node.y_max),
            ((node.x_min + node.x_max) / 2, (node.y_min + node.y_max) / 2)
        ]
        outputs = []
        for x, y in points:
            density = cppn.activate([x, y, 0, 0])[2]
            outputs.append(density)
        node.variance = np.var(outputs)
        return node.variance

    root = QuadTreeNode(x_min, x_max, y_min, y_max, max_depth=max_depth)
    nodes = [root]
    hidden_coordinates = []

    while nodes:
        node = nodes.pop(0)
        if node.depth >= node.max_depth:
            continue
        variance = compute_variance(node, cppn)
        if variance > variance_threshold:
            node.split()
            nodes.extend(node.children)
        else:
            x = (node.x_min + node.x_max) / 2
            y = (node.y_min + node.y_max) / 2
            node.place_neuron(x, y)
            hidden_coordinates.append((x, y))
    return hidden_coordinates

# %%
class ESHyperNEAT:
    def __init__(self, config_file, n_features):
        self.config_file = config_file
        self.n_features = n_features
        self.input_coordinates = [(0, i) for i in range(n_features)]
        self.output_coordinates = [(1, 0)]
        self.config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                                 neat.DefaultSpeciesSet, neat.DefaultStagnation,
                                 config_file)
    
    def eval_fitness(self, genomes, X_train, y_train):
        for genome_id, genome in genomes:
            cppn = neat.nn.FeedForwardNetwork.create(genome, self.config)
            hidden_coordinates = build_quadtree(cppn, x_min=0.3, x_max=0.7, y_min=-1, y_max=1, max_depth=4)
            substrate_weights = {}
            for src in self.input_coordinates + hidden_coordinates:
                for dst in hidden_coordinates + self.output_coordinates:
                    outputs = cppn.activate(src + dst)
                    weight = outputs[0]
                    connectivity = outputs[1]
                    if connectivity > 0:
                        substrate_weights[(src, dst)] = weight
            fitness = 0
            for xi, xo in zip(X_train, y_train):
                node_values = {coord: 0 for coord in self.input_coordinates + hidden_coordinates + self.output_coordinates}
                for i, coord in enumerate(self.input_coordinates):
                    node_values[coord] = xi[i]
                for (src, dst), weight in substrate_weights.items():
                    node_values[dst] += node_values[src] * weight
                output_value = node_values[(1, 0)]
                output_value = 1 / (1 + np.exp(-output_value))
                fitness += -xo * np.log(max(output_value, 1e-10)) - (1 - xo) * np.log(max(1 - output_value, 1e-10))
            genome.fitness = -fitness
    
    def run(self, X_train, y_train):
        p = neat.Population(self.config)
        p.add_reporter(neat.StdOutReporter(True))
        stats = neat.StatisticsReporter()
        p.add_reporter(stats)
        winner = p.run(lambda genomes, config: self.eval_fitness(genomes, X_train, y_train), 100)
        return winner
    
    def evaluate(self, X_test, y_test, winner):
        cppn = neat.nn.FeedForwardNetwork.create(winner, self.config)
        hidden_coordinates = build_quadtree(cppn, x_min=0.3, x_max=0.7, y_min=-1, y_max=1, max_depth=4)
        substrate_weights = {}
        for src in self.input_coordinates + hidden_coordinates:
            for dst in hidden_coordinates + self.output_coordinates:
                outputs = cppn.activate(src + dst)
                weight = outputs[0]
                connectivity = outputs[1]
                if connectivity > 0:
                    substrate_weights[(src, dst)] = weight
        predictions = []
        for xi in X_test:
            node_values = {coord: 0 for coord in self.input_coordinates + hidden_coordinates + self.output_coordinates}
            for i, coord in enumerate(self.input_coordinates):
                node_values[coord] = xi[i]
            for (src, dst), weight in substrate_weights.items():
                node_values[dst] += node_values[src] * weight
            output_value = node_values[(1, 0)]
            output_value = 1 / (1 + np.exp(-output_value))
            predictions.append(output_value)
        predicted_classes = [1 if p > 0.5 else 0 for p in predictions]
        f1 = f1_score(y_test, predicted_classes)
        print(f"Test F1-score: {f1}")
        return {
            'f1_score': f1,
            'winner': winner,
            'cppn': cppn,
            'hidden_coordinates': hidden_coordinates,
            'substrate_weights': substrate_weights
        }

# %%
# Обработка и обучение для df_small
X_small = df_small.drop('collision', axis=1)
y_small = df_small['collision']
scaler_small = StandardScaler()
X_small_scaled = scaler_small.fit_transform(X_small)
X_train_small, X_test_small, y_train_small, y_test_small = train_test_split(
    X_small_scaled, y_small, test_size=0.2, random_state=42
)

model_small = ESHyperNEAT('es_config.ini', n_features=4)
winner_small = model_small.run(X_train_small, y_train_small)
result_small = model_small.evaluate(X_test_small, y_test_small, winner_small)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: -108.25450 stdev: 136.49981
# Best fitness: -27.72589 - size: (3, 6) - species 1 - id 53
# Average adjusted fitness: 0.814
# Mean genetic distance 1.875, standard deviation 0.393
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   150    -27.7    0.814     0
# Total extinctions: 0
# Generation time: 0.203 sec
#
#  ****** Running generation 1 ******
# C:\Users\user\AppData\Local\Temp\ipykernel_18088\1928837208.py:31: RuntimeWarning: overflow encountered in exp
#   output_value = 1 / (1 + np.exp(-output_value))
# Population's average fitness: -30.72260 stdev: 15.10794
# Best fitness: -27.72589 - size: (3, 6) - species 1 - id 53
# Average adjusted fitness: 0.980
# Mean genetic distance 1.724, standard deviation 0.480
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   150    -27.7    0.980     1
# Total extinctions: 0
# Generation time: 0.150 sec (0.176 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -28.99891 stdev: 6.44642
# Best fitness: -27.72589 - size: (3, 5) - species 1 - id 194
# Average adjusted fitness: 0.978
# Mean genetic distance 1.745, standard deviation 0.456
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   150    -27.7    0.978     2
# Total extinctions: 0
# Generation time: 0.156 sec (0.170 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -32.20888 stdev: 35.54112
# Best fitness: -27.72589 - size: (3, 5) - species 1 - id 194
# Average adjusted fitness: 0.986
# Mean genetic distance 2.119, standard deviation 0.493
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   134    -27.7    0.986     3
#      2    0    16       --       --     0
# Total extinctions: 0
# Generation time: 0.175 sec (0.171 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -39.89647 stdev: 66.30764
# Best fitness: -27.72589 - size: (3, 5) - species 1 - id 194
# Average adjusted fitness: 0.979
# Mean genetic distance 2.235, standard deviation 0.567
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4   103    -27.7    0.968     4
#      2    1    47    -27.7    0.991     0
# Total extinctions: 0
# Generation time: 0.128 sec (0.162 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -36.75004 stdev: 59.72927
# Best fitness: -27.72589 - size: (3, 5) - species 1 - id 194
# Average adjusted fitness: 0.986
# Mean genetic distance 2.498, standard deviation 0.582
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    94    -27.7    0.971     5
#      2    2    52    -27.7    1.000     1
#      3    0     4       --       --     0
# Total extinctions: 0
# Generation time: 0.128 sec (0.157 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -34.89229 stdev: 50.09119
# Best fitness: -27.72589 - size: (3, 5) - species 1 - id 194
# Average adjusted fitness: 0.988
# Mean genetic distance 2.533, standard deviation 0.637
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    72    -27.7    0.988     6
#      2    3    44    -27.7    0.977     2
#      3    1    34    -27.7    1.000     0
# Total extinctions: 0
# Generation time: 0.176 sec (0.159 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -28.49538 stdev: 6.07483
# Best fitness: -27.72589 - size: (3, 5) - species 1 - id 194
# Average adjusted fitness: 0.988
# Mean genetic distance 2.568, standard deviation 0.563
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    73    -27.7    0.986     7
#      2    4    44    -27.7    0.978     3
#      3    2    33    -27.7    1.000     1
# Total extinctions: 0
# Generation time: 0.086 sec (0.150 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -28.79251 stdev: 7.11640
# Best fitness: -27.72589 - size: (3, 5) - species 1 - id 194
# Average adjusted fitness: 0.987
# Mean genetic distance 2.526, standard deviation 0.628
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    78    -27.7    0.965     8
#      2    5    41    -27.7    0.996     4
#      3    3    31    -27.7    1.000     2
# Total extinctions: 0
# Generation time: 0.060 sec (0.140 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -27.87739 stdev: 1.15643
# Best fitness: -27.72589 - size: (3, 5) - species 1 - id 194
# Average adjusted fitness: 0.981
# Mean genetic distance 2.499, standard deviation 0.645
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    68    -27.7    1.000     9
#      2    6    50    -27.7    0.944     5
#      3    4    32    -27.7    1.000     3
# Total extinctions: 0
# Generation time: 0.097 sec (0.136 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: -31.09138 stdev: 37.12584
# Best fitness: -27.72589 - size: (3, 5) - species 1 - id 194
# Average adjusted fitness: 0.995
# Mean genetic distance 2.486, standard deviation 0.625
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    53    -27.7    0.984    10
#      2    7    61    -27.7    1.000     6
#      3    5    37    -27.7    1.000     4
# Total extinctions: 0
# Generation time: 0.094 sec (0.125 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: -28.60037 stdev: 6.81082
# Best fitness: -27.72589 - size: (3, 5) - species 1 - id 194
# Average adjusted fitness: 0.986
# Mean genetic distance 2.487, standard deviation 0.588
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    69    -27.7    0.958    11
#      2    8    46    -27.7    1.000     7
#      3    6    31    -27.7    1.000     5
#      4    0     5       --       --     0
# Total extinctions: 0
# Generation time: 0.078 sec (0.118 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -28.40032 stdev: 5.12853
# Best fitness: -27.66160 - size: (7, 7) - species 2 - id 1826
# Average adjusted fitness: 0.992
# Mean genetic distance 2.541, standard deviation 0.624
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    65    -27.7    0.976    12
#      2    9    33    -27.7    0.995     0
#      3    7    24    -27.7    0.999     6
#      4    1    28    -27.7    0.999     0
# Total extinctions: 0
# Generation time: 0.066 sec (0.109 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -28.38121 stdev: 3.61346
# Best fitness: -27.66160 - size: (7, 7) - species 4 - id 1826
# Average adjusted fitness: 0.985
# Mean genetic distance 2.543, standard deviation 0.623
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    60    -27.7    0.968    13
#      2   10    22    -27.7    0.985     1
#      3    8    29    -27.7    0.998     7
#      4    2    34    -27.7    0.988     0
#      5    0     5       --       --     0
# Total extinctions: 0
# Generation time: 0.060 sec (0.097 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -28.72801 stdev: 5.90369
# Best fitness: -27.66160 - size: (7, 7) - species 4 - id 1826
# Average adjusted fitness: 0.983
# Mean genetic distance 2.500, standard deviation 0.661
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    51    -27.7    0.992    14
#      2   11    26    -27.7    0.978     2
#      3    9    23    -27.7    0.999     8
#      4    3    26    -27.7    0.947     1
#      5    1    24    -27.7    0.999     0
# Total extinctions: 0
# Generation time: 0.052 sec (0.090 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -30.27298 stdev: 16.99295
# Best fitness: -27.66160 - size: (7, 7) - species 4 - id 1826
# Average adjusted fitness: 0.990
# Mean genetic distance 2.474, standard deviation 0.670
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    46    -27.7    0.969    15
#      2   12    25    -27.7    0.998     3
#      3   10    27    -27.7    0.998     9
#      4    4    29    -27.7    0.988     2
#      5    2    23    -27.7    1.000     1
# Total extinctions: 0
# Generation time: 0.094 sec (0.086 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -30.80289 stdev: 29.86866
# Best fitness: -27.66160 - size: (7, 7) - species 4 - id 1826
# Average adjusted fitness: 0.994
# Mean genetic distance 2.467, standard deviation 0.660
# Population of 152 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    46    -27.7    0.975    16
#      2   13    29    -27.7    1.000     4
#      3   11    27    -27.7    1.000    10
#      4    5    28    -27.7    0.995     3
#      5    3    22    -27.7    1.000     2
# Total extinctions: 0
# Generation time: 0.109 sec (0.080 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -30.81018 stdev: 33.43813
# Best fitness: -27.66160 - size: (7, 7) - species 4 - id 1826
# Average adjusted fitness: 0.995
# Mean genetic distance 2.321, standard deviation 0.528
# Population of 152 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    51    -27.7    0.975    17
#      2   14    17    -27.7    1.000     5
#      3   12    22    -27.7    1.000    11
#      4    6    30    -27.7    1.000     4
#      5    4    32    -27.7    1.000     3
# Total extinctions: 0
# Generation time: 0.084 sec (0.079 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: -28.18799 stdev: 3.28515
# Best fitness: -27.66160 - size: (7, 7) - species 4 - id 1826
# Average adjusted fitness: 0.984
# Mean genetic distance 2.403, standard deviation 0.557
# Population of 151 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    54    -27.7    0.982    18
#      2   15    21    -27.7    0.998     6
#      3   13    24    -27.7    0.953    12
#      4    7    25    -27.7    0.990     5
#      5    5    24    -27.7    0.998     4
#      6    0     3       --       --     0
# Total extinctions: 0
# Generation time: 0.047 sec (0.078 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -31.14213 stdev: 26.71726
# Best fitness: -27.66160 - size: (7, 7) - species 4 - id 1826
# Average adjusted fitness: 0.988
# Mean genetic distance 2.467, standard deviation 0.634
# Population of 151 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    47    -27.7    0.997    19
#      2   16    23    -27.7    0.952     7
#      3   14    17    -27.7    1.000    13
#      4    8    22    -27.7    0.982     6
#      5    6    17    -27.7    1.000     5
#      6    1    25    -27.7    1.000     0
# Total extinctions: 0
# Generation time: 0.070 sec (0.075 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: -28.15708 stdev: 4.25651
# Best fitness: -27.66160 - size: (7, 7) - species 4 - id 1826
#
# Species 1 with 47 members is stagnated: removing it
# Average adjusted fitness: 0.979
# Mean genetic distance 2.394, standard deviation 0.630
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   17    32    -27.7    0.993     8
#      3   15    32    -27.7    0.993    14
#      4    9    28    -27.7    0.924     7
#      5    7    26    -27.7    0.993     6
#      6    2    32    -27.7    0.993     1
# Total extinctions: 0
# Generation time: 0.090 sec (0.075 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: -27.81145 stdev: 0.61879
# Best fitness: -27.66160 - size: (7, 7) - species 4 - id 1826
# Average adjusted fitness: 0.973
# Mean genetic distance 2.456, standard deviation 0.661
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   18    30    -27.7    0.989     9
#      3   16    21    -27.7    0.958    15
#      4   10    33    -27.7    0.969     8
#      5    8    29    -27.7    0.961     7
#      6    3    37    -27.7    0.989     2
# Total extinctions: 0
# Generation time: 0.081 sec (0.075 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: -28.36738 stdev: 4.43797
# Best fitness: -27.66160 - size: (7, 7) - species 4 - id 1826
# Average adjusted fitness: 0.984
# Mean genetic distance 2.370, standard deviation 0.568
# Population of 152 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   19    33    -27.7    0.998    10
#      3   17    30    -27.7    0.998    16
#      4   11    35    -27.7    0.928     9
#      5    9    28    -27.7    0.998     8
#      6    4    26    -27.7    0.998     3
# Total extinctions: 0
# Generation time: 0.052 sec (0.074 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: -27.82514 stdev: 0.92994
# Best fitness: -27.66160 - size: (7, 7) - species 4 - id 1826
# Average adjusted fitness: 0.985
# Mean genetic distance 2.407, standard deviation 0.592
# Population of 152 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   20    30    -27.7    0.994    11
#      3   18    39    -27.7    0.994    17
#      4   12    34    -27.7    0.966    10
#      5   10    27    -27.7    0.994     9
#      6    5    22    -27.7    0.978     4
# Total extinctions: 0
# Generation time: 0.062 sec (0.074 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: -28.38643 stdev: 5.13115
# Best fitness: -27.66160 - size: (7, 7) - species 4 - id 1826
# Average adjusted fitness: 0.989
# Mean genetic distance 2.427, standard deviation 0.631
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   21    30    -27.7    0.988    12
#      3   19    38    -27.7    0.999    18
#      4   13    37    -27.7    0.958    11
#      5   11    25    -27.7    0.999    10
#      6    6    21    -27.7    0.999     5
# Total extinctions: 0
# Generation time: 0.080 sec (0.077 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: -29.62140 stdev: 13.28788
# Best fitness: -27.63571 - size: (7, 7) - species 4 - id 3723
# Average adjusted fitness: 0.988
# Mean genetic distance 2.569, standard deviation 0.598
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   22    31    -27.7    0.959    13
#      3   20    40    -27.7    0.999    19
#      4   14    27    -27.6    0.980     0
#      5   12    34    -27.7    0.999    11
#      6    7    18    -27.7    0.999     6
# Total extinctions: 0
# Generation time: 0.088 sec (0.076 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: -31.02292 stdev: 28.35219
# Best fitness: -27.63571 - size: (7, 7) - species 4 - id 3723
#
# Species 3 with 40 members is stagnated: removing it
# Average adjusted fitness: 0.988
# Mean genetic distance 2.511, standard deviation 0.612
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   23    51    -27.7    0.963    14
#      4   15    33    -27.6    0.989     1
#      5   13    36    -27.7    1.000    12
#      6    8    30    -27.7    1.000     7
# Total extinctions: 0
# Generation time: 0.109 sec (0.076 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: -29.06057 stdev: 8.21369
# Best fitness: -27.63571 - size: (7, 7) - species 4 - id 3723
# Average adjusted fitness: 0.987
# Mean genetic distance 2.478, standard deviation 0.661
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   24    46    -27.7    0.968    15
#      4   16    32    -27.6    0.983     2
#      5   14    39    -27.7    0.999    13
#      6    9    33    -27.7    0.999     8
# Total extinctions: 0
# Generation time: 0.222 sec (0.090 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: -28.80176 stdev: 4.64412
# Best fitness: -27.63571 - size: (7, 7) - species 4 - id 3723
# Average adjusted fitness: 0.963
# Mean genetic distance 2.438, standard deviation 0.629
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   25    60    -27.7    0.979    16
#      4   17    33    -27.6    0.878     3
#      5   15    31    -27.7    0.997    14
#      6   10    25    -27.7    0.997     9
# Total extinctions: 0
# Generation time: 0.180 sec (0.103 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: -30.28709 stdev: 10.07106
# Best fitness: -27.63571 - size: (7, 7) - species 4 - id 3723
# Average adjusted fitness: 0.959
# Mean genetic distance 2.446, standard deviation 0.674
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   26    53    -27.7    0.973    17
#      4   18    34    -27.6    0.865     4
#      5   16    31    -27.7    0.999    15
#      6   11    32    -27.7    0.999    10
# Total extinctions: 0
# Generation time: 0.168 sec (0.113 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: -28.96325 stdev: 5.79994
# Best fitness: -27.63571 - size: (7, 7) - species 4 - id 3723
# Average adjusted fitness: 0.975
# Mean genetic distance 2.431, standard deviation 0.614
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   27    52    -27.7    0.979    18
#      4   19    44    -27.6    0.922     5
#      5   17    30    -27.7    0.998    16
#      6   12    24    -27.7    0.998    11
# Total extinctions: 0
# Generation time: 0.171 sec (0.121 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: -31.76567 stdev: 32.28147
# Best fitness: -27.63571 - size: (7, 7) - species 4 - id 3723
# Average adjusted fitness: 0.992
# Mean genetic distance 2.350, standard deviation 0.616
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   28    49    -27.7    0.977    19
#      4   20    37    -27.6    0.991     6
#      5   18    37    -27.7    1.000    17
#      6   13    27    -27.7    1.000    12
# Total extinctions: 0
# Generation time: 0.153 sec (0.129 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: -32.20500 stdev: 36.20349
# Best fitness: -27.63571 - size: (7, 7) - species 4 - id 3723
# Average adjusted fitness: 0.991
# Mean genetic distance 2.425, standard deviation 0.610
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   29    46    -27.7    0.968    20
#      4   21    39    -27.6    0.998     7
#      5   19    33    -27.7    1.000    18
#      6   14    33    -27.7    1.000    13
# Total extinctions: 0
# Generation time: 0.132 sec (0.137 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: -34.08973 stdev: 45.98162
# Best fitness: -27.63571 - size: (7, 7) - species 4 - id 3723
# Average adjusted fitness: 0.987
# Mean genetic distance 2.483, standard deviation 0.641
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   30    63    -27.7    0.954    21
#      4   22    29    -27.6    0.994     8
#      5   20    27    -27.7    1.000    19
#      6   15    30    -27.7    1.000    14
# Total extinctions: 0
# Generation time: 0.159 sec (0.146 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: -35.15452 stdev: 50.12379
# Best fitness: -27.63571 - size: (7, 7) - species 4 - id 3723
#
# Species 5 with 27 members is stagnated: removing it
# Average adjusted fitness: 0.984
# Mean genetic distance 2.440, standard deviation 0.725
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   31    65    -27.6    0.969     0
#      4   23    42    -27.6    0.987     9
#      6   16    43    -27.7    0.995    15
# Total extinctions: 0
# Generation time: 0.152 sec (0.153 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: -29.11484 stdev: 6.44552
# Best fitness: -27.63571 - size: (7, 7) - species 4 - id 3723
# Average adjusted fitness: 0.974
# Mean genetic distance 2.504, standard deviation 0.635
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   32    61    -27.6    0.979     1
#      4   24    45    -27.6    0.968    10
#      6   17    45    -27.7    0.975    16
# Total extinctions: 0
# Generation time: 0.218 sec (0.166 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: -32.13153 stdev: 37.33212
# Best fitness: -27.63571 - size: (7, 7) - species 4 - id 3723
# Average adjusted fitness: 0.991
# Mean genetic distance 2.598, standard deviation 0.643
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   33    62    -27.6    0.980     2
#      4   25    43    -27.6    0.995    11
#      6   18    42    -27.7    1.000    17
#      7    0     4       --       --     0
# Total extinctions: 0
# Generation time: 0.166 sec (0.172 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: -30.10133 stdev: 12.18809
# Best fitness: -27.00037 - size: (4, 6) - species 2 - id 5362
# Average adjusted fitness: 0.983
# Mean genetic distance 2.668, standard deviation 0.684
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   34    49    -27.0    0.957     0
#      4   26    45    -27.7    0.984    12
#      6   19    37    -27.7    0.994    18
#      7    1    19    -27.7    0.994     0
# Total extinctions: 0
# Generation time: 0.147 sec (0.165 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: -30.35599 stdev: 11.19742
# Best fitness: -27.00037 - size: (4, 6) - species 2 - id 5362
# Average adjusted fitness: 0.960
# Mean genetic distance 2.727, standard deviation 0.664
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   35    41    -27.0    0.962     1
#      4   27    41    -27.6    0.950    13
#      6   20    49    -27.7    0.972    19
#      7    2    19    -27.7    0.956     1
# Total extinctions: 0
# Generation time: 0.108 sec (0.157 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: -30.55354 stdev: 11.21013
# Best fitness: -27.00037 - size: (4, 6) - species 2 - id 5362
#
# Species 6 with 49 members is stagnated: removing it
# Average adjusted fitness: 0.921
# Mean genetic distance 2.577, standard deviation 0.739
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   36    56    -27.0    0.865     2
#      4   28    52    -27.6    0.963    14
#      7    3    42    -27.7    0.936     2
# Total extinctions: 0
# Generation time: 0.062 sec (0.147 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: -29.61232 stdev: 7.47146
# Best fitness: -27.00037 - size: (4, 6) - species 2 - id 5362
# Average adjusted fitness: 0.956
# Mean genetic distance 2.563, standard deviation 0.698
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   37    58    -27.0    0.977     3
#      4   29    48    -27.6    0.928    15
#      7    4    44    -27.7    0.964     3
# Total extinctions: 0
# Generation time: 0.091 sec (0.139 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: -30.00835 stdev: 8.89680
# Best fitness: -27.00037 - size: (4, 6) - species 2 - id 5362
# Average adjusted fitness: 0.949
# Mean genetic distance 2.580, standard deviation 0.685
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   38    55    -27.0    0.961     4
#      4   30    47    -27.6    0.943    16
#      7    5    48    -27.7    0.943     4
# Total extinctions: 0
# Generation time: 0.087 sec (0.132 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: -36.88053 stdev: 48.26152
# Best fitness: -27.00037 - size: (4, 6) - species 2 - id 5362
# Average adjusted fitness: 0.980
# Mean genetic distance 2.684, standard deviation 0.747
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   39    55    -27.0    0.953     5
#      4   31    46    -27.6    0.990    17
#      7    6    46    -27.7    0.995     5
#      8    0     3       --       --     0
# Total extinctions: 0
# Generation time: 0.089 sec (0.128 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: -31.59830 stdev: 27.76681
# Best fitness: -27.00037 - size: (4, 6) - species 2 - id 5362
# Average adjusted fitness: 0.990
# Mean genetic distance 2.787, standard deviation 0.720
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   40    67    -27.0    0.970     6
#      4   32    20    -27.6    0.993    18
#      7    7    43    -27.7    0.998     6
#      8    1    20    -27.7    0.998     0
# Total extinctions: 0
# Generation time: 0.137 sec (0.126 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: -34.66857 stdev: 49.34055
# Best fitness: -27.00037 - size: (4, 6) - species 2 - id 5362
# Average adjusted fitness: 0.990
# Mean genetic distance 2.758, standard deviation 0.666
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   41    61    -27.0    0.970     7
#      4   33    25    -27.7    0.996    19
#      7    8    43    -27.7    0.996     7
#      8    2    21    -27.7    0.997     1
# Total extinctions: 0
# Generation time: 0.093 sec (0.120 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: -32.79352 stdev: 38.15095
# Best fitness: -27.00037 - size: (4, 6) - species 2 - id 5362
# Average adjusted fitness: 0.991
# Mean genetic distance 2.804, standard deviation 0.727
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   42    66    -27.0    0.977     8
#      4   34    18    -27.3    0.995     0
#      7    9    42    -27.7    0.992     8
#      8    3    23    -27.7    0.998     2
# Total extinctions: 0
# Generation time: 0.095 sec (0.107 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: -29.24582 stdev: 6.43467
# Best fitness: -27.00037 - size: (4, 6) - species 2 - id 5362
# Average adjusted fitness: 0.956
# Mean genetic distance 2.744, standard deviation 0.668
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   43    53    -27.0    0.961     9
#      4   35    30    -27.3    0.937     1
#      7   10    41    -27.7    0.987     9
#      8    4    25    -27.7    0.940     3
# Total extinctions: 0
# Generation time: 0.086 sec (0.099 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: -36.59026 stdev: 51.56913
# Best fitness: -27.00037 - size: (4, 6) - species 2 - id 5362
# Average adjusted fitness: 0.984
# Mean genetic distance 2.800, standard deviation 0.694
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   44    55    -27.0    0.961    10
#      4   36    12    -27.3    0.988     2
#      7   11    34    -27.7    0.988    10
#      8    5    27    -27.7    0.998     4
#      9    0    22       --       --     0
# Total extinctions: 0
# Generation time: 0.155 sec (0.100 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: -35.11053 stdev: 49.21100
# Best fitness: -27.00037 - size: (4, 6) - species 2 - id 5362
# Average adjusted fitness: 0.988
# Mean genetic distance 2.830, standard deviation 0.690
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   45    47    -27.0    0.965    11
#      4   37    15    -27.7    0.994     3
#      7   12    33    -27.7    0.995    11
#      8    6    24    -27.7    0.998     5
#      9    1    31    -27.3    0.986     0
# Total extinctions: 0
# Generation time: 0.080 sec (0.097 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: -28.89422 stdev: 5.62249
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.963
# Mean genetic distance 2.778, standard deviation 0.656
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   46    46    -27.0    0.979    12
#      4   38    17    -27.7    0.973     4
#      7   13    30    -27.7    0.986    12
#      8    7    24    -27.7    0.927     6
#      9    2    33    -26.9    0.952     0
# Total extinctions: 0
# Generation time: 0.134 sec (0.105 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: -32.83715 stdev: 35.95123
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.989
# Mean genetic distance 2.730, standard deviation 0.745
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   47    40    -27.0    0.973     0
#      4   39    23    -27.7    0.993     5
#      7   14    30    -27.7    0.993    13
#      8    8    28    -27.7    0.998     7
#      9    3    30    -26.9    0.986     1
# Total extinctions: 0
# Generation time: 0.138 sec (0.109 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: -29.71241 stdev: 8.74013
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.955
# Mean genetic distance 2.721, standard deviation 0.788
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   48    43    -27.0    0.946     1
#      4   40    20    -27.7    0.986     6
#      7   15    33    -27.7    0.953    14
#      8    9    24    -27.7    0.986     8
#      9    4    29    -26.9    0.904     2
# Total extinctions: 0
# Generation time: 0.100 sec (0.111 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: -29.89965 stdev: 7.02323
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.941
# Mean genetic distance 2.771, standard deviation 0.817
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   49    37    -27.0    0.941     2
#      4   41    26    -27.7    0.976     7
#      7   16    32    -27.7    0.954    15
#      8   10    28    -27.7    0.982     9
#      9    5    28    -26.9    0.850     3
# Total extinctions: 0
# Generation time: 0.042 sec (0.106 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: -32.46292 stdev: 37.68230
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.989
# Mean genetic distance 2.848, standard deviation 0.774
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   50    34    -27.0    0.969     3
#      4   42    26    -27.7    0.997     8
#      7   17    30    -27.7    0.994    16
#      8   11    25    -27.7    0.998    10
#      9    6    31    -26.9    0.986     4
#     10    0     4       --       --     0
# Total extinctions: 0
# Generation time: 0.052 sec (0.098 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: -29.98434 stdev: 7.59912
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.951
# Mean genetic distance 2.898, standard deviation 0.769
# Population of 151 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   51    29    -27.0    0.876     4
#      4   43    26    -27.7    0.984     9
#      7   18    24    -27.7    0.958    17
#      8   12    12    -27.7    0.984    11
#      9    7    28    -26.9    0.922     5
#     10    1    24    -27.7    0.984     0
#     11    0     8       --       --     0
# Total extinctions: 0
# Generation time: 0.043 sec (0.093 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: -29.03215 stdev: 5.70367
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.968
# Mean genetic distance 2.904, standard deviation 0.752
# Population of 151 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   52    26    -27.0    0.940     5
#      4   44    23    -27.7    0.985    10
#      7   19    25    -27.7    0.944    18
#      8   13    15    -27.7    0.985    12
#      9    8    24    -26.9    0.949     6
#     10    2    21    -27.7    0.985     1
#     11    1    17    -27.7    0.985     0
# Total extinctions: 0
# Generation time: 0.049 sec (0.088 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: -32.82821 stdev: 37.19947
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.988
# Mean genetic distance 2.917, standard deviation 0.719
# Population of 150 members in 8 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   53    24    -27.0    0.953     6
#      4   45    22    -27.7    0.998    11
#      7   20    23    -27.7    0.988    19
#      8   14    20    -27.7    0.998    13
#      9    9    25    -26.9    0.986     7
#     10    3    15    -27.7    0.998     2
#     11    2    16    -27.7    0.998     1
#     12    0     5       --       --     0
# Total extinctions: 0
# Generation time: 0.047 sec (0.084 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: -29.52556 stdev: 8.96399
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
#
# Species 7 with 23 members is stagnated: removing it
# Average adjusted fitness: 0.963
# Mean genetic distance 2.897, standard deviation 0.833
# Population of 150 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   54    26    -27.0    0.950     7
#      4   46    23    -27.7    0.987    12
#      8   15    24    -27.7    0.987    14
#      9   10    22    -26.9    0.860     8
#     10    4    15    -27.7    0.987     3
#     11    3    17    -27.7    0.987     2
#     12    1    23    -27.7    0.987     0
# Total extinctions: 0
# Generation time: 0.044 sec (0.073 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: -30.58404 stdev: 10.29752
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.953
# Mean genetic distance 2.803, standard deviation 0.833
# Population of 149 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   55    25    -27.0    0.911     8
#      4   47    22    -27.7    0.988    13
#      8   16    25    -27.7    0.988    15
#      9   11    19    -26.9    0.816     9
#     10    5    21    -27.7    0.988     4
#     11    4    19    -27.7    0.988     3
#     12    2    18    -27.7    0.988     1
# Total extinctions: 0
# Generation time: 0.040 sec (0.069 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: -28.62641 stdev: 4.71951
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.958
# Mean genetic distance 2.815, standard deviation 0.792
# Population of 149 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   56    23    -27.0    0.908     9
#      4   48    20    -27.7    0.968    14
#      8   17    22    -27.7    0.979    16
#      9   12    21    -26.9    0.915    10
#     10    6    22    -27.7    0.979     5
#     11    5    21    -27.7    0.979     4
#     12    3    20    -27.7    0.979     2
# Total extinctions: 0
# Generation time: 0.046 sec (0.060 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: -30.29637 stdev: 10.16432
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.956
# Mean genetic distance 2.802, standard deviation 0.773
# Population of 152 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   57    25    -27.0    0.937    10
#      4   49    21    -27.7    0.982    15
#      8   18    27    -27.7    0.989    17
#      9   13    20    -26.9    0.851    11
#     10    7    23    -27.7    0.989     6
#     11    6    19    -27.7    0.952     5
#     12    4    17    -27.7    0.989     3
# Total extinctions: 0
# Generation time: 0.039 sec (0.050 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: -29.37009 stdev: 8.47737
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.960
# Mean genetic distance 2.810, standard deviation 0.785
# Population of 152 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   58    26    -27.0    0.974    11
#      4   50    22    -27.7    0.979    16
#      8   19    25    -27.7    0.987    18
#      9   14    20    -26.9    0.818    12
#     10    8    19    -27.7    0.987     7
#     11    7    21    -27.7    0.987     6
#     12    5    19    -27.7    0.987     4
# Total extinctions: 0
# Generation time: 0.064 sec (0.047 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: -29.10492 stdev: 6.87089
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.961
# Mean genetic distance 2.778, standard deviation 0.735
# Population of 149 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   59    28    -27.0    0.964    12
#      4   51    21    -27.7    0.986    17
#      8   20    23    -27.7    0.986    19
#      9   15    20    -26.9    0.838    13
#     10    9    19    -27.7    0.986     8
#     11    8    20    -27.7    0.986     7
#     12    6    18    -27.7    0.986     5
# Total extinctions: 0
# Generation time: 0.043 sec (0.047 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: -29.54296 stdev: 8.67482
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
#
# Species 8 with 23 members is stagnated: removing it
# Average adjusted fitness: 0.951
# Mean genetic distance 2.706, standard deviation 0.753
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   60    35    -27.0    0.958    13
#      4   52    22    -27.7    0.986    18
#      9   16    26    -26.9    0.852    14
#     10   10    15    -27.7    0.986     9
#     11    9    29    -27.7    0.938     8
#     12    7    23    -27.7    0.986     6
# Total extinctions: 0
# Generation time: 0.069 sec (0.048 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: -30.78172 stdev: 13.29044
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.967
# Mean genetic distance 2.768, standard deviation 0.762
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   61    30    -27.0    0.943    14
#      4   53    25    -27.7    0.992    19
#      9   17    27    -26.9    0.892    15
#     10   11    24    -27.7    0.992    10
#     11   10    28    -27.7    0.992     9
#     12    8    16    -27.7    0.992     7
# Total extinctions: 0
# Generation time: 0.061 sec (0.050 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: -30.96899 stdev: 26.06463
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
#
# Species 4 with 25 members is stagnated: removing it
# Average adjusted fitness: 0.987
# Mean genetic distance 2.701, standard deviation 0.747
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   62    38    -27.0    0.988    15
#      9   18    34    -26.9    0.953    16
#     10   12    27    -27.7    0.997    11
#     11   11    33    -27.7    0.997    10
#     12    9    18    -27.7    0.997     8
# Total extinctions: 0
# Generation time: 0.069 sec (0.052 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: -41.45940 stdev: 66.60407
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.971
# Mean genetic distance 2.656, standard deviation 0.762
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   63    40    -27.0    0.966    16
#      9   19    28    -26.9    0.894    17
#     10   13    31    -27.7    0.998    12
#     11   12    33    -27.7    0.998    11
#     12   10    18    -27.7    0.998     9
# Total extinctions: 0
# Generation time: 0.091 sec (0.057 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: -36.81057 stdev: 56.31861
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.977
# Mean genetic distance 2.663, standard deviation 0.712
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   64    40    -27.0    0.970    17
#      9   20    31    -26.9    0.920    18
#     10   14    26    -27.7    0.998    13
#     11   13    30    -27.7    0.997    12
#     12   11    23    -27.7    0.998    10
# Total extinctions: 0
# Generation time: 0.063 sec (0.058 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: -33.69110 stdev: 34.49417
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.983
# Mean genetic distance 2.692, standard deviation 0.718
# Population of 151 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   65    31    -27.0    0.990    18
#      9   21    26    -26.9    0.934    19
#     10   15    32    -27.7    0.998    14
#     11   14    29    -27.7    0.998    13
#     12   12    18    -27.7    0.998    11
#     13    0    15       --       --     0
# Total extinctions: 0
# Generation time: 0.077 sec (0.062 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: -29.69384 stdev: 7.94937
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.956
# Mean genetic distance 2.760, standard deviation 0.702
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   66    22    -27.0    0.924    19
#      9   22    23    -26.9    0.917    20
#     10   16    28    -27.7    0.955    15
#     11   15    22    -27.7    0.986    14
#     12   13    18    -27.7    0.986    12
#     13    1    37    -27.2    0.966     0
# Total extinctions: 0
# Generation time: 0.073 sec (0.065 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: -39.94750 stdev: 60.81815
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.975
# Mean genetic distance 2.778, standard deviation 0.732
# Population of 151 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   67    23    -27.0    0.982    20
#      9   23    24    -26.9    0.943    21
#     10   17    23    -27.7    0.998    16
#     11   16    29    -27.7    0.998    15
#     12   14    20    -27.7    0.998    13
#     13    2    32    -27.2    0.934     1
# Total extinctions: 0
# Generation time: 0.079 sec (0.069 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: -43.63070 stdev: 72.74056
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.964
# Mean genetic distance 2.768, standard deviation 0.741
# Population of 151 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   68    22    -27.0    0.953    21
#      9   24    23    -26.9    0.934    22
#     10   18    23    -27.7    0.998    17
#     11   17    26    -27.7    0.998    16
#     12   15    22    -27.7    0.998    14
#     13    3    35    -27.2    0.906     2
# Total extinctions: 0
# Generation time: 0.139 sec (0.076 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: -47.34605 stdev: 84.57786
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.959
# Mean genetic distance 2.816, standard deviation 0.770
# Population of 151 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   69    20    -27.0    0.877    22
#      9   25    24    -26.9    0.918    23
#     10   19    23    -27.7    0.998    18
#     11   18    22    -27.7    0.998    17
#     12   16    24    -27.7    0.998    15
#     13    4    38    -27.2    0.966     3
# Total extinctions: 0
# Generation time: 0.193 sec (0.091 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: -49.60967 stdev: 84.73883
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.961
# Mean genetic distance 2.779, standard deviation 0.729
# Population of 149 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   70    22    -27.0    0.952    23
#      9   26    23    -26.9    0.905    24
#     10   20    22    -27.7    0.998    19
#     11   19    22    -27.7    0.998    18
#     12   17    26    -27.7    0.994    16
#     13    5    34    -27.2    0.919     4
# Total extinctions: 0
# Generation time: 0.166 sec (0.101 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: -38.22973 stdev: 58.96838
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
#
# Species 10 with 22 members is stagnated: removing it
# Average adjusted fitness: 0.976
# Mean genetic distance 2.689, standard deviation 0.762
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   71    27    -27.0    0.990    24
#      9   27    29    -26.9    0.988    25
#     11   20    29    -27.7    0.998    19
#     12   18    28    -27.7    0.998    17
#     13    6    36    -27.1    0.904     0
# Total extinctions: 0
# Generation time: 0.127 sec (0.108 average)
#
#  ****** Running generation 75 ******
#
# Population's average fitness: -39.65265 stdev: 55.63869
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
#
# Species 11 with 29 members is stagnated: removing it
# Average adjusted fitness: 0.963
# Mean genetic distance 2.551, standard deviation 0.743
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   72    36    -27.0    0.950    25
#      9   28    37    -26.9    0.962    26
#     12   19    36    -27.7    0.998    18
#     13    7    41    -27.1    0.943     1
#     14    0     1       --       --     0
# Total extinctions: 0
# Generation time: 0.193 sec (0.120 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: -57.04637 stdev: 94.38285
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.954
# Mean genetic distance 2.613, standard deviation 0.747
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   73    30    -27.0    0.979    26
#      9   29    34    -26.9    0.977    27
#     12   20    28    -27.7    0.998    19
#     13    8    42    -27.1    0.820     2
#     14    1    16    -27.7    0.998     0
# Total extinctions: 0
# Generation time: 0.216 sec (0.133 average)
#
#  ****** Running generation 77 ******
#
# Population's average fitness: -48.90824 stdev: 84.87720
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
#
# Species 12 with 28 members is stagnated: removing it
# Average adjusted fitness: 0.957
# Mean genetic distance 2.528, standard deviation 0.765
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   74    44    -27.0    0.976    27
#      9   30    38    -26.9    0.913    28
#     13    9    36    -27.1    0.940     0
#     14    2    31    -27.7    0.998     1
#     15    0     2       --       --     0
# Total extinctions: 0
# Generation time: 0.163 sec (0.143 average)
#
#  ****** Running generation 78 ******
#
# Population's average fitness: -35.75593 stdev: 38.38561
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.979
# Mean genetic distance 2.548, standard deviation 0.731
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   75    34    -27.0    0.989    28
#      9   31    32    -26.9    0.965    29
#     13   10    42    -27.1    0.967     1
#     14    3    30    -27.7    0.998     2
#     15    1    12    -27.7    0.978     0
# Total extinctions: 0
# Generation time: 0.172 sec (0.152 average)
#
#  ****** Running generation 79 ******
#
# Population's average fitness: -48.03871 stdev: 85.16287
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.965
# Mean genetic distance 2.571, standard deviation 0.758
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   76    32    -27.0    0.995    29
#      9   32    31    -26.9    0.894    30
#     13   11    36    -27.1    0.938     2
#     14    4    31    -27.7    0.998     3
#     15    2    21    -27.7    0.998     1
# Total extinctions: 0
# Generation time: 0.120 sec (0.157 average)
#
#  ****** Running generation 80 ******
#
# Population's average fitness: -38.90528 stdev: 51.90968
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.970
# Mean genetic distance 2.584, standard deviation 0.721
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   77    33    -27.0    0.957    30
#      9   33    28    -26.9    0.954    31
#     13   12    32    -27.1    0.947     3
#     14    5    32    -27.7    0.997     4
#     15    3    25    -27.7    0.998     2
# Total extinctions: 0
# Generation time: 0.100 sec (0.159 average)
#
#  ****** Running generation 81 ******
#
# Population's average fitness: -37.44498 stdev: 58.63498
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.974
# Mean genetic distance 2.632, standard deviation 0.748
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   78    30    -27.0    0.994    31
#      9   34    27    -26.9    0.886    32
#     13   13    34    -27.1    0.995     4
#     14    6    31    -27.7    0.998     5
#     15    4    27    -27.7    0.998     3
# Total extinctions: 0
# Generation time: 0.087 sec (0.154 average)
#
#  ****** Running generation 82 ******
#
# Population's average fitness: -30.95105 stdev: 17.05004
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.980
# Mean genetic distance 2.666, standard deviation 0.769
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   79    28    -27.0    0.989    32
#      9   35    29    -26.9    0.979    33
#     13   14    34    -27.1    0.942     5
#     14    7    30    -27.7    0.996     6
#     15    5    28    -27.7    0.996     4
# Total extinctions: 0
# Generation time: 0.115 sec (0.146 average)
#
#  ****** Running generation 83 ******
#
# Population's average fitness: -41.50163 stdev: 65.19225
# Best fitness: -26.85599 - size: (6, 6) - species 9 - id 7105
# Average adjusted fitness: 0.967
# Mean genetic distance 2.666, standard deviation 0.741
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   80    27    -27.0    0.962    33
#      9   36    29    -26.9    0.938    34
#     13   15    38    -27.1    0.939     6
#     14    8    31    -27.7    0.998     7
#     15    6    26    -27.7    0.998     5
# Total extinctions: 0
# Generation time: 0.080 sec (0.137 average)
#
#  ****** Running generation 84 ******
#
# Population's average fitness: -33.28779 stdev: 41.50613
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
#
# Species 2 with 27 members is stagnated: removing it
# Average adjusted fitness: 0.988
# Mean genetic distance 2.619, standard deviation 0.806
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   37    35    -26.9    0.996    35
#     13   16    42    -26.8    0.964     0
#     14    9    38    -27.7    0.992     8
#     15    7    35    -27.7    0.998     6
# Total extinctions: 0
# Generation time: 0.054 sec (0.130 average)
#
#  ****** Running generation 85 ******
#
# Population's average fitness: -39.29580 stdev: 60.44635
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.971
# Mean genetic distance 2.638, standard deviation 0.783
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   38    36    -26.9    0.907    36
#     13   17    44    -26.8    0.986     1
#     14   10    38    -27.7    0.998     9
#     15    8    32    -27.7    0.995     7
# Total extinctions: 0
# Generation time: 0.072 sec (0.118 average)
#
#  ****** Running generation 86 ******
#
# Population's average fitness: -36.78695 stdev: 48.26007
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.978
# Mean genetic distance 2.654, standard deviation 0.749
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   39    35    -26.9    0.931    37
#     13   18    48    -26.8    0.985     2
#     14   11    39    -27.7    0.998    10
#     15    9    28    -27.7    0.998     8
# Total extinctions: 0
# Generation time: 0.066 sec (0.103 average)
#
#  ****** Running generation 87 ******
#
# Population's average fitness: -30.78533 stdev: 10.65515
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.945
# Mean genetic distance 2.604, standard deviation 0.760
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   40    36    -26.9    0.893    38
#     13   19    47    -26.8    0.940     3
#     14   12    38    -27.7    0.960    11
#     15   10    30    -27.7    0.987     9
# Total extinctions: 0
# Generation time: 0.065 sec (0.093 average)
#
#  ****** Running generation 88 ******
#
# Population's average fitness: -33.58646 stdev: 32.47926
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.982
# Mean genetic distance 2.611, standard deviation 0.746
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   41    37    -26.9    0.970    39
#     13   20    44    -26.8    0.970     4
#     14   13    39    -27.7    0.997    12
#     15   11    30    -27.7    0.992    10
# Total extinctions: 0
# Generation time: 0.121 sec (0.088 average)
#
#  ****** Running generation 89 ******
#
# Population's average fitness: -39.83022 stdev: 62.16772
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.975
# Mean genetic distance 2.633, standard deviation 0.756
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   42    36    -26.9    0.937    40
#     13   21    44    -26.8    0.967     5
#     14   14    38    -27.7    0.998    13
#     15   12    31    -27.7    0.998    11
# Total extinctions: 0
# Generation time: 0.098 sec (0.086 average)
#
#  ****** Running generation 90 ******
#
# Population's average fitness: -34.27228 stdev: 36.70328
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.984
# Mean genetic distance 2.655, standard deviation 0.750
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   43    37    -26.9    0.981    41
#     13   22    44    -26.8    0.961     6
#     14   15    39    -27.7    0.998    14
#     15   13    31    -27.7    0.998    12
# Total extinctions: 0
# Generation time: 0.110 sec (0.087 average)
#
#  ****** Running generation 91 ******
#
# Population's average fitness: -32.45887 stdev: 32.70187
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.986
# Mean genetic distance 2.639, standard deviation 0.756
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   44    36    -26.9    0.955    42
#     13   23    43    -26.8    0.992     7
#     14   16    38    -27.7    0.998    15
#     15   14    32    -27.7    0.998    13
# Total extinctions: 0
# Generation time: 0.114 sec (0.090 average)
#
#  ****** Running generation 92 ******
#
# Population's average fitness: -31.89749 stdev: 25.98725
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.983
# Mean genetic distance 2.652, standard deviation 0.750
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   45    37    -26.9    0.946    43
#     13   24    43    -26.8    0.991     8
#     14   17    39    -27.7    0.997    16
#     15   15    32    -27.7    0.997    14
# Total extinctions: 0
# Generation time: 0.087 sec (0.087 average)
#
#  ****** Running generation 93 ******
#
# Population's average fitness: -34.07317 stdev: 37.82917
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.983
# Mean genetic distance 2.658, standard deviation 0.741
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   46    33    -26.9    0.961    44
#     13   25    44    -26.8    0.981     9
#     14   18    38    -27.7    0.998    17
#     15   16    34    -27.7    0.994    15
# Total extinctions: 0
# Generation time: 0.085 sec (0.087 average)
#
#  ****** Running generation 94 ******
#
# Population's average fitness: -36.80549 stdev: 59.11086
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.982
# Mean genetic distance 2.634, standard deviation 0.755
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   47    34    -26.9    0.966    45
#     13   26    41    -26.8    0.964    10
#     14   19    39    -27.7    0.998    18
#     15   17    36    -27.7    0.998    16
# Total extinctions: 0
# Generation time: 0.097 sec (0.092 average)
#
#  ****** Running generation 95 ******
#
# Population's average fitness: -42.18073 stdev: 68.11956
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.967
# Mean genetic distance 2.635, standard deviation 0.704
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   48    35    -26.9    0.922    46
#     13   27    43    -26.8    0.951    11
#     14   20    37    -27.7    0.998    19
#     15   18    34    -27.7    0.998    17
# Total extinctions: 0
# Generation time: 0.083 sec (0.093 average)
#
#  ****** Running generation 96 ******
#
# Population's average fitness: -40.02764 stdev: 64.07995
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
#
# Species 14 with 37 members is stagnated: removing it
# Average adjusted fitness: 0.968
# Mean genetic distance 2.507, standard deviation 0.766
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   49    50    -26.9    0.939    47
#     13   28    56    -26.8    0.966    12
#     15   19    44    -27.7    0.998    18
# Total extinctions: 0
# Generation time: 0.106 sec (0.097 average)
#
#  ****** Running generation 97 ******
#
# Population's average fitness: -47.14433 stdev: 82.93033
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.959
# Mean genetic distance 2.462, standard deviation 0.750
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   50    48    -26.9    0.940    48
#     13   29    55    -26.8    0.963    13
#     15   20    46    -27.7    0.973    19
# Total extinctions: 0
# Generation time: 0.133 sec (0.104 average)
#
#  ****** Running generation 98 ******
#
# Population's average fitness: -37.43064 stdev: 42.71462
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
#
# Species 15 with 46 members is stagnated: removing it
# Average adjusted fitness: 0.967
# Mean genetic distance 2.023, standard deviation 0.795
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   51    73    -26.9    0.956    49
#     13   30    77    -26.8    0.977    14
# Total extinctions: 0
# Generation time: 0.102 sec (0.102 average)
#
#  ****** Running generation 99 ******
#
# Population's average fitness: -36.03137 stdev: 30.07668
# Best fitness: -26.81015 - size: (3, 5) - species 13 - id 11931
# Average adjusted fitness: 0.965
# Mean genetic distance 2.067, standard deviation 0.714
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   52    69    -26.9    0.963    50
#     13   31    81    -26.8    0.967    15
# Total extinctions: 0
# Generation time: 0.127 sec (0.104 average)
# Test F1-score: 0.6666666666666666

# %%
# Обработка и обучение для df_large
X_large = df_large.drop('collision', axis=1)
y_large = df_large['collision']
scaler_large = StandardScaler()
X_large_scaled = scaler_large.fit_transform(X_large)
X_train_large, X_test_large, y_train_large, y_test_large = train_test_split(
    X_large_scaled, y_large, test_size=0.2, random_state=42
)

model_large = ESHyperNEAT('es_config.ini', n_features=6)
winner_large = model_large.run(X_train_large, y_train_large)
result_large = model_large.evaluate(X_test_large, y_test_large, winner_large)
# Out:
#  ****** Running generation 0 ******
# C:\Users\user\AppData\Local\Temp\ipykernel_18088\1928837208.py:31: RuntimeWarning: overflow encountered in exp
#   output_value = 1 / (1 + np.exp(-output_value))
# Population's average fitness: -1813.82008 stdev: 2065.51042
# Best fitness: -553.10514 - size: (3, 6) - species 1 - id 31
# Average adjusted fitness: 0.848
# Mean genetic distance 1.816, standard deviation 0.352
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   143   -553.1    0.848     0
#      2    0     7       --       --     0
# Total extinctions: 0
# Generation time: 1.863 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -1152.87181 stdev: 1678.55386
# Best fitness: -552.88577 - size: (4, 7) - species 1 - id 182
# Average adjusted fitness: 0.956
# Mean genetic distance 1.860, standard deviation 0.442
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    55   -552.9    0.932     0
#      2    1    95   -553.9    0.981     0
# Total extinctions: 0
# Generation time: 1.853 sec (1.858 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -1040.08319 stdev: 1741.10988
# Best fitness: -552.65478 - size: (4, 6) - species 2 - id 419
# Average adjusted fitness: 0.924
# Mean genetic distance 1.930, standard deviation 0.409
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    99   -553.1    0.859     1
#      2    2    51   -552.7    0.988     0
# Total extinctions: 0
# Generation time: 3.231 sec (2.316 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -952.81100 stdev: 1375.53288
# Best fitness: -551.50538 - size: (3, 5) - species 1 - id 546
# Average adjusted fitness: 0.955
# Mean genetic distance 2.120, standard deviation 0.410
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    72   -551.5    0.943     0
#      2    3    78   -553.1    0.968     1
# Total extinctions: 0
# Generation time: 2.492 sec (2.360 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -895.54963 stdev: 1132.47611
# Best fitness: -551.50538 - size: (3, 5) - species 1 - id 546
# Average adjusted fitness: 0.958
# Mean genetic distance 2.077, standard deviation 0.403
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    99   -551.5    0.944     1
#      2    4    51   -552.7    0.971     2
# Total extinctions: 0
# Generation time: 2.794 sec (2.446 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -925.95079 stdev: 1236.61447
# Best fitness: -551.50538 - size: (3, 5) - species 1 - id 546
# Average adjusted fitness: 0.962
# Mean genetic distance 2.051, standard deviation 0.372
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5   121   -551.5    0.953     2
#      2    5    29   -553.1    0.970     3
# Total extinctions: 0
# Generation time: 2.301 sec (2.422 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -731.98086 stdev: 895.66855
# Best fitness: -551.50538 - size: (3, 5) - species 1 - id 546
# Average adjusted fitness: 0.983
# Mean genetic distance 1.991, standard deviation 0.419
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6   132   -551.5    0.975     3
#      2    6    18   -553.1    0.991     4
# Total extinctions: 0
# Generation time: 1.840 sec (2.339 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -776.27266 stdev: 771.49998
# Best fitness: -551.50538 - size: (3, 5) - species 1 - id 546
# Average adjusted fitness: 0.971
# Mean genetic distance 2.003, standard deviation 0.528
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   103   -551.5    0.963     4
#      2    7    47   -553.1    0.979     5
# Total extinctions: 0
# Generation time: 1.332 sec (2.213 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -713.68713 stdev: 444.06283
# Best fitness: -550.79363 - size: (3, 3) - species 1 - id 1235
# Average adjusted fitness: 0.898
# Mean genetic distance 2.078, standard deviation 0.617
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    91   -550.8    0.950     0
#      2    8    59   -553.1    0.845     6
# Total extinctions: 0
# Generation time: 1.988 sec (2.188 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -795.83797 stdev: 989.64963
# Best fitness: -550.79363 - size: (3, 3) - species 1 - id 1235
# Average adjusted fitness: 0.969
# Mean genetic distance 2.128, standard deviation 0.581
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    86   -550.8    0.975     1
#      2    9    64   -553.1    0.963     7
# Total extinctions: 0
# Generation time: 0.977 sec (2.067 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: -775.53029 stdev: 704.47977
# Best fitness: -550.79363 - size: (3, 3) - species 1 - id 1235
# Average adjusted fitness: 0.967
# Mean genetic distance 2.169, standard deviation 0.466
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    84   -550.8    0.963     2
#      2   10    66   -552.7    0.971     8
# Total extinctions: 0
# Generation time: 1.058 sec (1.986 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: -901.65498 stdev: 1224.02043
# Best fitness: -550.79363 - size: (3, 3) - species 1 - id 1235
# Average adjusted fitness: 0.958
# Mean genetic distance 2.225, standard deviation 0.477
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    71   -550.8    0.975     3
#      2   11    79   -552.7    0.941     9
# Total extinctions: 0
# Generation time: 2.697 sec (2.071 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -980.01407 stdev: 1531.32154
# Best fitness: -550.79363 - size: (3, 3) - species 2 - id 1235
# Average adjusted fitness: 0.953
# Mean genetic distance 2.146, standard deviation 0.465
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    84   -551.3    0.957     4
#      2   12    66   -550.8    0.950     0
# Total extinctions: 0
# Generation time: 2.199 sec (1.968 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -797.30305 stdev: 955.43145
# Best fitness: -550.79363 - size: (3, 3) - species 2 - id 1235
# Average adjusted fitness: 0.971
# Mean genetic distance 2.148, standard deviation 0.477
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    93   -551.3    0.959     5
#      2   13    57   -550.8    0.984     1
# Total extinctions: 0
# Generation time: 2.210 sec (1.939 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -806.20988 stdev: 1003.98750
# Best fitness: -550.79363 - size: (3, 3) - species 1 - id 1235
# Average adjusted fitness: 0.972
# Mean genetic distance 2.111, standard deviation 0.477
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14   110   -550.8    0.960     6
#      2   14    40   -552.1    0.985     2
# Total extinctions: 0
# Generation time: 1.647 sec (1.825 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -752.96282 stdev: 929.04893
# Best fitness: -550.76666 - size: (5, 4) - species 1 - id 2244
# Average adjusted fitness: 0.977
# Mean genetic distance 2.071, standard deviation 0.505
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    91   -550.8    0.972     0
#      2   15    59   -552.1    0.982     3
# Total extinctions: 0
# Generation time: 0.909 sec (1.686 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -664.75002 stdev: 282.10296
# Best fitness: -550.76666 - size: (5, 4) - species 2 - id 2244
# Average adjusted fitness: 0.928
# Mean genetic distance 2.027, standard deviation 0.458
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16   101   -550.8    0.900     1
#      2   16    49   -550.8    0.956     0
# Total extinctions: 0
# Generation time: 1.903 sec (1.692 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -664.54048 stdev: 320.55935
# Best fitness: -550.76666 - size: (5, 4) - species 2 - id 2244
# Average adjusted fitness: 0.929
# Mean genetic distance 2.119, standard deviation 0.452
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    82   -550.8    0.951     2
#      2   17    68   -550.8    0.906     1
# Total extinctions: 0
# Generation time: 1.182 sec (1.677 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: -798.39869 stdev: 1142.39892
# Best fitness: -550.76666 - size: (5, 4) - species 2 - id 2244
# Average adjusted fitness: 0.971
# Mean genetic distance 2.082, standard deviation 0.521
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18   117   -550.8    0.955     3
#      2   18    33   -550.8    0.987     2
# Total extinctions: 0
# Generation time: 1.350 sec (1.613 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -839.65990 stdev: 1213.12685
# Best fitness: -550.76666 - size: (5, 4) - species 1 - id 2244
# Average adjusted fitness: 0.974
# Mean genetic distance 1.947, standard deviation 0.496
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    84   -550.8    0.957     4
#      2   19    66   -551.8    0.992     3
# Total extinctions: 0
# Generation time: 1.362 sec (1.652 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: -788.34499 stdev: 1024.87119
# Best fitness: -550.76666 - size: (5, 4) - species 2 - id 2244
# Average adjusted fitness: 0.973
# Mean genetic distance 2.165, standard deviation 0.499
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20    69   -550.8    0.956     5
#      2   20    81   -550.8    0.990     4
# Total extinctions: 0
# Generation time: 1.682 sec (1.714 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: -875.45214 stdev: 1326.60661
# Best fitness: -550.76666 - size: (5, 4) - species 2 - id 2244
# Average adjusted fitness: 0.958
# Mean genetic distance 2.276, standard deviation 0.407
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21    75   -552.5    0.923     6
#      2   21    75   -550.8    0.993     5
# Total extinctions: 0
# Generation time: 1.655 sec (1.610 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: -700.04276 stdev: 714.09200
# Best fitness: -550.76666 - size: (5, 4) - species 1 - id 2244
# Average adjusted fitness: 0.982
# Mean genetic distance 2.270, standard deviation 0.447
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22    95   -550.8    0.971     7
#      2   22    55   -550.8    0.992     6
# Total extinctions: 0
# Generation time: 1.927 sec (1.583 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: -827.30453 stdev: 1099.74541
# Best fitness: -550.76666 - size: (5, 4) - species 1 - id 2244
# Average adjusted fitness: 0.967
# Mean genetic distance 2.221, standard deviation 0.428
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23    66   -550.8    0.964     8
#      2   23    84   -551.6    0.971     7
# Total extinctions: 0
# Generation time: 2.665 sec (1.628 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: -755.07824 stdev: 862.08056
# Best fitness: -550.76666 - size: (5, 4) - species 2 - id 2244
# Average adjusted fitness: 0.975
# Mean genetic distance 2.135, standard deviation 0.454
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24    67   -550.8    0.977     9
#      2   24    83   -550.8    0.974     8
# Total extinctions: 0
# Generation time: 2.108 sec (1.674 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: -792.30289 stdev: 949.21522
# Best fitness: -550.76666 - size: (5, 4) - species 2 - id 2244
# Average adjusted fitness: 0.969
# Mean genetic distance 2.240, standard deviation 0.506
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25   106   -550.8    0.955    10
#      2   25    44   -550.8    0.983     9
# Total extinctions: 0
# Generation time: 1.973 sec (1.781 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: -800.55422 stdev: 1015.90399
# Best fitness: -550.65051 - size: (6, 9) - species 1 - id 3848
# Average adjusted fitness: 0.974
# Mean genetic distance 2.294, standard deviation 0.535
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26   109   -550.7    0.969     0
#      2   26    41   -550.8    0.979    10
# Total extinctions: 0
# Generation time: 1.279 sec (1.718 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: -738.24856 stdev: 744.10650
# Best fitness: -550.65051 - size: (6, 9) - species 1 - id 3848
# Average adjusted fitness: 0.980
# Mean genetic distance 2.198, standard deviation 0.544
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27   107   -550.7    0.974     1
#      2   27    43   -550.8    0.986    11
# Total extinctions: 0
# Generation time: 2.146 sec (1.815 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: -896.06030 stdev: 1305.88878
# Best fitness: -550.65051 - size: (6, 9) - species 1 - id 3848
# Average adjusted fitness: 0.966
# Mean genetic distance 2.202, standard deviation 0.557
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28   100   -550.7    0.947     2
#      2   28    50   -550.8    0.985    12
# Total extinctions: 0
# Generation time: 2.971 sec (1.977 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: -782.66421 stdev: 890.27878
# Best fitness: -549.84702 - size: (5, 3) - species 2 - id 4267
# Average adjusted fitness: 0.973
# Mean genetic distance 2.184, standard deviation 0.590
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29    92   -550.7    0.966     3
#      2   29    58   -549.8    0.980     0
# Total extinctions: 0
# Generation time: 1.979 sec (2.039 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: -765.29497 stdev: 805.10164
# Best fitness: -549.84702 - size: (5, 3) - species 2 - id 4267
# Average adjusted fitness: 0.976
# Mean genetic distance 2.267, standard deviation 0.566
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30    66   -550.7    0.965     4
#      2   30    84   -549.8    0.988     1
# Total extinctions: 0
# Generation time: 1.566 sec (2.027 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: -687.27945 stdev: 394.56568
# Best fitness: -549.43410 - size: (4, 3) - species 2 - id 4662
# Average adjusted fitness: 0.930
# Mean genetic distance 2.425, standard deviation 0.651
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31    79   -550.7    0.903     5
#      2   31    61   -549.4    0.958     0
#      3    0    10       --       --     0
# Total extinctions: 0
# Generation time: 0.913 sec (1.953 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: -855.22116 stdev: 1167.07987
# Best fitness: -549.43410 - size: (4, 3) - species 2 - id 4662
# Average adjusted fitness: 0.946
# Mean genetic distance 2.503, standard deviation 0.637
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32    67   -550.7    0.958     6
#      2   32    50   -549.4    0.980     1
#      3    1    33   -553.1    0.899     0
# Total extinctions: 0
# Generation time: 1.899 sec (1.950 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: -688.48838 stdev: 790.83636
# Best fitness: -549.43410 - size: (4, 3) - species 2 - id 4662
# Average adjusted fitness: 0.987
# Mean genetic distance 2.576, standard deviation 0.665
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33    65   -550.7    0.976     7
#      2   33    55   -549.4    0.991     2
#      3    2    31   -553.1    0.994     0
# Total extinctions: 0
# Generation time: 1.920 sec (1.875 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: -868.65827 stdev: 1201.31567
# Best fitness: -549.43410 - size: (4, 3) - species 2 - id 4662
# Average adjusted fitness: 0.967
# Mean genetic distance 2.656, standard deviation 0.629
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34    49   -550.7    0.958     8
#      2   34    53   -549.4    0.965     3
#      3    3    48   -553.1    0.977     1
# Total extinctions: 0
# Generation time: 2.036 sec (1.868 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: -664.32534 stdev: 678.74525
# Best fitness: -549.43410 - size: (4, 3) - species 2 - id 4662
# Average adjusted fitness: 0.986
# Mean genetic distance 2.676, standard deviation 0.683
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35    73   -550.7    0.970     9
#      2   35    45   -549.4    0.993     4
#      3    4    33   -553.1    0.994     2
# Total extinctions: 0
# Generation time: 1.701 sec (1.841 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: -687.86028 stdev: 324.64857
# Best fitness: -549.43410 - size: (4, 3) - species 2 - id 4662
# Average adjusted fitness: 0.918
# Mean genetic distance 2.691, standard deviation 0.660
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36    49   -550.7    0.893    10
#      2   36    50   -549.4    0.950     5
#      3    5    38   -553.1    0.910     3
#      4    0    13       --       --     0
# Total extinctions: 0
# Generation time: 1.701 sec (1.883 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: -707.24190 stdev: 831.41702
# Best fitness: -549.43410 - size: (4, 3) - species 2 - id 4662
# Average adjusted fitness: 0.982
# Mean genetic distance 2.642, standard deviation 0.698
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37    32   -550.7    0.958    11
#      2   37    43   -549.4    0.991     6
#      3    6    24   -553.1    0.996     4
#      4    1    52   -553.2    0.981     0
# Total extinctions: 0
# Generation time: 2.046 sec (1.873 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: -774.59524 stdev: 992.78432
# Best fitness: -549.43410 - size: (4, 3) - species 2 - id 4662
# Average adjusted fitness: 0.971
# Mean genetic distance 2.481, standard deviation 0.707
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38    33   -550.7    0.921    12
#      2   38    40   -549.4    0.977     7
#      3    7    42   -553.1    0.999     5
#      4    2    35   -553.1    0.989     0
# Total extinctions: 0
# Generation time: 1.708 sec (1.747 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: -658.29330 stdev: 285.11727
# Best fitness: -549.43410 - size: (4, 3) - species 2 - id 4662
# Average adjusted fitness: 0.938
# Mean genetic distance 2.489, standard deviation 0.624
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39    31   -550.7    0.923    13
#      2   39    39   -549.4    0.960     8
#      3    8    49   -552.6    0.927     0
#      4    3    31   -553.1    0.941     0
# Total extinctions: 0
# Generation time: 1.674 sec (1.716 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: -809.07759 stdev: 1169.95755
# Best fitness: -549.43410 - size: (4, 3) - species 2 - id 4662
# Average adjusted fitness: 0.969
# Mean genetic distance 2.505, standard deviation 0.599
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40    33   -550.7    0.939    14
#      2   40    39   -549.4    0.993     9
#      3    9    43   -552.6    0.952     1
#      4    4    35   -553.1    0.993     1
# Total extinctions: 0
# Generation time: 1.875 sec (1.747 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: -702.41126 stdev: 376.90841
# Best fitness: -549.43410 - size: (4, 3) - species 2 - id 4662
# Average adjusted fitness: 0.916
# Mean genetic distance 2.548, standard deviation 0.620
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41    36   -550.7    0.920    15
#      2   41    37   -549.4    0.898    10
#      3   10    15   -552.6    0.913     2
#      4    5    37   -553.1    0.931     2
#      5    0    16       --       --     0
#      6    0     9       --       --     0
# Total extinctions: 0
# Generation time: 1.106 sec (1.767 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: -825.25166 stdev: 1183.99978
# Best fitness: -549.03102 - size: (5, 3) - species 2 - id 6227
# Average adjusted fitness: 0.957
# Mean genetic distance 2.699, standard deviation 0.693
# Population of 149 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42    29   -550.7    0.967    16
#      2   42    30   -549.0    0.987     0
#      3   11    31   -552.6    0.917     3
#      4    6    21   -553.0    0.983     0
#      5    1    15   -553.1    0.935     0
#      6    1    23   -553.8    0.952     0
# Total extinctions: 0
# Generation time: 2.276 sec (1.804 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: -844.08992 stdev: 1330.82565
# Best fitness: -549.03102 - size: (5, 3) - species 2 - id 6227
# Average adjusted fitness: 0.965
# Mean genetic distance 2.599, standard deviation 0.740
# Population of 148 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43    26   -550.7    0.992    17
#      2   43    28   -549.0    0.991     1
#      3   12    22   -552.6    0.987     0
#      4    7    20   -552.6    0.954     0
#      5    2    30   -553.1    0.990     1
#      6    2    22   -553.1    0.874     0
# Total extinctions: 0
# Generation time: 1.342 sec (1.746 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: -682.65189 stdev: 754.47791
# Best fitness: -549.03102 - size: (5, 3) - species 2 - id 6227
# Average adjusted fitness: 0.980
# Mean genetic distance 2.547, standard deviation 0.733
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44    25   -550.7    0.985    18
#      2   44    27   -549.0    0.995     2
#      3   13    26   -552.6    0.999     1
#      4    8    22   -552.8    0.988     1
#      5    3    27   -552.6    0.994     0
#      6    3    23   -553.1    0.917     0
# Total extinctions: 0
# Generation time: 1.508 sec (1.694 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: -736.05909 stdev: 911.19374
# Best fitness: -549.03102 - size: (5, 3) - species 2 - id 6227
# Average adjusted fitness: 0.977
# Mean genetic distance 2.549, standard deviation 0.728
# Population of 151 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45    26   -550.7    0.986    19
#      2   45    26   -549.0    0.986     3
#      3   14    29   -552.5    0.995     0
#      4    9    22   -551.6    0.989     0
#      5    4    24   -552.6    0.955     1
#      6    4    24   -553.1    0.952     1
# Total extinctions: 0
# Generation time: 1.036 sec (1.627 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: -660.84725 stdev: 513.79020
# Best fitness: -549.03102 - size: (5, 3) - species 2 - id 6227
# Average adjusted fitness: 0.981
# Mean genetic distance 2.466, standard deviation 0.701
# Population of 151 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46    25   -550.1    0.957     0
#      2   46    25   -549.0    0.985     4
#      3   15    24   -552.3    0.985     0
#      4   10    32   -551.6    0.999     1
#      5    5    21   -552.6    0.984     2
#      6    5    24   -553.1    0.975     2
# Total extinctions: 0
# Generation time: 0.981 sec (1.555 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: -658.19947 stdev: 287.19421
# Best fitness: -549.03102 - size: (5, 3) - species 2 - id 6227
# Average adjusted fitness: 0.941
# Mean genetic distance 2.527, standard deviation 0.655
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   47    24   -550.1    0.912     1
#      2   47    25   -549.0    0.962     5
#      3   16     3   -552.4    0.955     1
#      4   11    38   -551.6    0.980     2
#      5    6    37   -553.1    0.960     3
#      6    6    23   -553.1    0.879     0
# Total extinctions: 0
# Generation time: 0.772 sec (1.428 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: -646.06029 stdev: 682.08724
# Best fitness: -549.03102 - size: (5, 3) - species 2 - id 6227
# Average adjusted fitness: 0.988
# Mean genetic distance 2.597, standard deviation 0.646
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   48    24   -550.1    0.948     2
#      2   48    25   -549.0    0.998     6
#      3   17    15   -553.3    0.999     2
#      4   12    34   -551.6    0.998     3
#      5    7    29   -552.6    0.996     4
#      6    7    23   -552.9    0.989     0
# Total extinctions: 0
# Generation time: 1.031 sec (1.360 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: -645.72538 stdev: 297.97168
# Best fitness: -549.03102 - size: (5, 3) - species 2 - id 6227
# Average adjusted fitness: 0.946
# Mean genetic distance 2.584, standard deviation 0.698
# Population of 152 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   49    25   -550.1    0.947     3
#      2   49    24   -549.0    0.974     7
#      3   18    31   -551.6    0.977     0
#      4   13    22   -551.6    0.960     0
#      5    8    25   -552.6    0.944     5
#      6    8    25   -552.9    0.878     1
# Total extinctions: 0
# Generation time: 1.125 sec (1.305 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: -615.04792 stdev: 229.79039
# Best fitness: -549.03102 - size: (5, 3) - species 2 - id 6227
# Average adjusted fitness: 0.963
# Mean genetic distance 2.532, standard deviation 0.708
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   50    25   -550.1    0.981     4
#      2   50    23   -549.0    0.930     8
#      3   19    29   -551.7    0.970     1
#      4   14    21   -551.6    0.979     1
#      5    9    26   -553.1    0.984     6
#      6    9    26   -552.9    0.934     2
# Total extinctions: 0
# Generation time: 0.761 sec (1.194 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: -605.34542 stdev: 216.36719
# Best fitness: -549.03102 - size: (5, 3) - species 2 - id 6227
# Average adjusted fitness: 0.969
# Mean genetic distance 2.536, standard deviation 0.728
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   51    26   -550.1    0.979     0
#      2   51    24   -549.0    0.937     9
#      3   20    29   -551.6    0.969     0
#      4   15    22   -551.6    0.989     2
#      5   10    26   -552.8    0.996     7
#      6   10    23   -552.9    0.942     3
# Total extinctions: 0
# Generation time: 1.097 sec (1.193 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: -680.53348 stdev: 365.46854
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.949
# Mean genetic distance 2.515, standard deviation 0.717
# Population of 148 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   52    24   -550.1    0.940     1
#      2   52    23   -548.8    0.904     0
#      3   21    24   -551.6    0.954     1
#      4   16    28   -551.6    0.981     3
#      5   11    26   -552.8    0.941     8
#      6   11    23   -552.9    0.971     4
# Total extinctions: 0
# Generation time: 1.204 sec (1.086 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: -698.16554 stdev: 931.24154
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.981
# Mean genetic distance 2.586, standard deviation 0.736
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   53    25   -550.1    0.955     2
#      2   53    23   -548.8    0.997     1
#      3   22    23   -551.6    0.992     0
#      4   17    30   -551.6    0.996     4
#      5   12    25   -552.8    0.993     9
#      6   12    24   -552.9    0.955     5
# Total extinctions: 0
# Generation time: 0.920 sec (1.044 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: -649.80524 stdev: 369.83431
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.963
# Mean genetic distance 2.631, standard deviation 0.705
# Population of 151 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   54    28   -549.5    0.978     0
#      2   54    22   -548.8    0.950     2
#      3   23    16   -551.6    0.971     1
#      4   18    38   -551.6    0.991     5
#      5   13    25   -552.8    0.953    10
#      6   13    22   -552.9    0.938     6
# Total extinctions: 0
# Generation time: 0.730 sec (0.966 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: -802.84357 stdev: 1148.97356
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.970
# Mean genetic distance 2.605, standard deviation 0.684
# Population of 149 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   55    27   -549.5    0.995     1
#      2   55    23   -548.8    0.949     3
#      3   24    34   -551.6    0.987     2
#      4   19    18   -551.6    0.965     0
#      5   14    24   -552.8    0.954    11
#      6   14    23   -551.7    0.970     0
# Total extinctions: 0
# Generation time: 1.463 sec (1.008 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: -671.41309 stdev: 702.59133
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.983
# Mean genetic distance 2.569, standard deviation 0.679
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   56    27   -549.5    0.983     2
#      2   56    23   -548.8    0.998     4
#      3   25    27   -551.6    0.987     3
#      4   20    24   -551.6    0.941     1
#      5   15    25   -552.8    0.994    12
#      6   15    24   -551.7    0.998     1
# Total extinctions: 0
# Generation time: 0.982 sec (1.008 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: -603.89433 stdev: 222.31526
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.970
# Mean genetic distance 2.582, standard deviation 0.678
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   57    28   -549.5    0.959     3
#      2   57    24   -548.8    0.995     5
#      3   26    14   -551.6    0.986     4
#      4   21    36   -551.6    0.989     2
#      5   16    23   -552.8    0.915    13
#      6   16    25   -551.7    0.975     2
# Total extinctions: 0
# Generation time: 0.835 sec (1.015 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: -604.98520 stdev: 219.81786
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.968
# Mean genetic distance 2.643, standard deviation 0.730
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   58    27   -549.5    0.978     4
#      2   58    25   -548.8    0.992     6
#      3   27    26   -551.6    0.968     5
#      4   22    24   -551.6    0.975     3
#      5   17    24   -552.5    0.988     0
#      6   17    24   -551.7    0.910     3
# Total extinctions: 0
# Generation time: 0.828 sec (0.994 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: -648.65243 stdev: 288.10723
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.945
# Mean genetic distance 2.645, standard deviation 0.680
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   59    26   -549.5    0.908     5
#      2   59    24   -548.8    0.928     7
#      3   28    36   -551.6    0.960     6
#      4   23    14   -551.3    0.928     0
#      5   18    25   -552.5    0.964     1
#      6   18    25   -551.7    0.981     4
# Total extinctions: 0
# Generation time: 0.871 sec (0.969 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: -600.69369 stdev: 197.26654
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.967
# Mean genetic distance 2.624, standard deviation 0.661
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   60    25   -549.5    0.991     6
#      2   60    25   -548.8    0.994     8
#      3   29     4   -551.3    0.974     0
#      4   24    46   -551.6    0.930     1
#      5   19    26   -552.4    0.971     0
#      6   19    24   -551.7    0.943     5
# Total extinctions: 0
# Generation time: 1.191 sec (1.012 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: -701.84843 stdev: 700.40112
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.978
# Mean genetic distance 2.617, standard deviation 0.647
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   61    26   -549.5    0.917     7
#      2   61    26   -548.8    0.995     9
#      3   30    24   -552.4    0.999     1
#      4   25    24   -551.3    0.975     2
#      5   20    25   -552.4    0.998     1
#      6   20    25   -551.7    0.986     6
# Total extinctions: 0
# Generation time: 1.109 sec (1.013 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: -736.23276 stdev: 984.84254
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.977
# Mean genetic distance 2.613, standard deviation 0.629
# Population of 152 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   62    25   -549.5    0.948     8
#      2   62    25   -548.8    0.970    10
#      3   31    38   -551.3    0.957     2
#      4   26    12   -551.6    0.996     3
#      5   21    26   -552.4    0.994     2
#      6   21    26   -551.7    0.999     7
# Total extinctions: 0
# Generation time: 0.973 sec (0.990 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: -803.20323 stdev: 1191.85811
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.973
# Mean genetic distance 2.616, standard deviation 0.667
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   63    27   -549.5    0.911     9
#      2   63    28   -548.8    0.995    11
#      3   32     6   -551.3    0.966     3
#      4   27    38   -551.6    0.993     4
#      5   22    25   -552.3    0.995     0
#      6   22    26   -551.7    0.977     8
# Total extinctions: 0
# Generation time: 2.060 sec (1.104 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: -634.80986 stdev: 636.33473
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.990
# Mean genetic distance 2.710, standard deviation 0.648
# Population of 152 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   64    29   -549.5    0.955    10
#      2   64    25   -548.8    0.997    12
#      3   33    14   -552.4    0.999     4
#      4   28    20   -551.3    0.997     5
#      5   23    26   -552.3    0.997     1
#      6   23    25   -551.7    0.993     9
#      7    0    13       --       --     0
# Total extinctions: 0
# Generation time: 1.185 sec (1.150 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: -748.24507 stdev: 810.99431
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.973
# Mean genetic distance 2.720, standard deviation 0.593
# Population of 151 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   65    25   -549.5    0.991    11
#      2   65    23   -548.8    0.980    13
#      3   34     1   -551.6    0.957     5
#      4   29     4   -552.4    0.913     6
#      5   24    24   -552.3    0.993     2
#      6   24    23   -551.7    0.993    10
#      7    1    51   -551.3    0.983     0
# Total extinctions: 0
# Generation time: 1.569 sec (1.160 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: -648.26017 stdev: 301.43106
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.953
# Mean genetic distance 2.631, standard deviation 0.672
# Population of 150 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   66    24   -549.5    0.936    12
#      2   66    21   -548.8    0.946    14
#      3   35    16   -554.5    0.997     6
#      4   30     3   -554.5    0.899     7
#      5   25    23   -552.3    0.994     3
#      6   25    22   -551.7    0.997    11
#      7    2    41   -551.3    0.904     1
# Total extinctions: 0
# Generation time: 0.647 sec (1.127 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: -664.06026 stdev: 690.24192
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.984
# Mean genetic distance 2.670, standard deviation 0.658
# Population of 149 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   67    23   -549.5    0.994    13
#      2   67    22   -548.8    0.979    15
#      3   36     1   -554.5    0.933     7
#      4   31    29   -554.5    0.999     8
#      5   26    22   -552.3    0.996     4
#      6   26    21   -551.7    0.995    12
#      7    3    31   -551.3    0.993     2
# Total extinctions: 0
# Generation time: 0.978 sec (1.141 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: -634.47424 stdev: 295.70222
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.955
# Mean genetic distance 2.590, standard deviation 0.673
# Population of 149 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   68    23   -549.5    0.982    14
#      2   68    20   -548.8    0.898    16
#      3   37    16   -554.5    0.997     8
#      4   32    20   -554.5    0.948     9
#      5   27    22   -552.3    0.884     5
#      6   27    22   -551.7    0.996    13
#      7    4    26   -551.3    0.977     3
# Total extinctions: 0
# Generation time: 0.656 sec (1.124 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: -748.06976 stdev: 939.10293
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.976
# Mean genetic distance 2.645, standard deviation 0.651
# Population of 149 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   69    22   -549.5    0.945    15
#      2   69    21   -548.8    0.995    17
#      3   38    12   -554.5    0.990     9
#      4   33    27   -553.9    0.947    10
#      5   28    22   -552.3    0.986     6
#      6   28    20   -551.7    0.976    14
#      7    5    25   -551.3    0.993     4
# Total extinctions: 0
# Generation time: 0.841 sec (1.121 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: -617.67235 stdev: 217.68367
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.957
# Mean genetic distance 2.650, standard deviation 0.627
# Population of 148 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   70    21   -549.5    0.979    16
#      2   70    21   -548.8    0.991    18
#      3   39    19   -554.5    0.914    10
#      4   34    21   -553.6    0.952    11
#      5   29    21   -552.3    0.960     7
#      6   29    21   -551.7    0.938    15
#      7    6    24   -551.3    0.967     5
# Total extinctions: 0
# Generation time: 0.669 sec (1.069 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: -610.64830 stdev: 176.48264
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.955
# Mean genetic distance 2.677, standard deviation 0.653
# Population of 152 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   71    22   -549.5    0.950    17
#      2   71    22   -548.8    0.965    19
#      3   40    29   -554.5    0.990    11
#      4   35    12   -553.6    0.860    12
#      5   30    22   -552.3    0.988     8
#      6   30    22   -551.7    0.951    16
#      7    7    23   -551.3    0.977     6
# Total extinctions: 0
# Generation time: 1.078 sec (1.066 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: -743.78204 stdev: 966.18618
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.978
# Mean genetic distance 2.678, standard deviation 0.609
# Population of 148 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   72    22   -549.5    0.960    18
#      2   72    22   -548.8    0.980    20
#      3   41    22   -554.5    0.999    12
#      4   36    17   -553.6    0.980    13
#      5   31    22   -552.3    0.996     9
#      6   31    21   -551.7    0.988    17
#      7    8    22   -551.3    0.940     7
# Total extinctions: 0
# Generation time: 0.825 sec (1.051 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: -759.20080 stdev: 1180.12835
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.976
# Mean genetic distance 2.702, standard deviation 0.585
# Population of 153 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   73    23   -549.5    0.955    19
#      2   73    21   -548.8    0.999    21
#      3   42    32   -554.5    0.954    13
#      4   37     9   -553.6    0.938    14
#      5   32    23   -552.3    0.989    10
#      6   32    22   -551.7    0.997    18
#      7    9    23   -551.3    0.998     8
# Total extinctions: 0
# Generation time: 1.448 sec (0.990 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: -692.44276 stdev: 653.85731
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.972
# Mean genetic distance 2.689, standard deviation 0.601
# Population of 150 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   74    23   -549.5    0.967    20
#      2   74    23   -548.8    0.989    22
#      3   43    23   -553.6    0.992    14
#      4   38    14   -554.5    0.886    15
#      5   33    22   -552.3    0.994    11
#      6   33    21   -551.7    0.984    19
#      7   10    24   -551.3    0.994     9
# Total extinctions: 0
# Generation time: 1.085 sec (0.980 average)
#
#  ****** Running generation 75 ******
#
# Population's average fitness: -782.07643 stdev: 1066.46227
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
#
# Species 6 with 21 members is stagnated: removing it
# Average adjusted fitness: 0.971
# Mean genetic distance 2.640, standard deviation 0.622
# Population of 152 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   75    29   -549.5    0.895    21
#      2   75    26   -548.8    0.996    23
#      3   44    12   -553.1    0.942    15
#      4   39    26   -554.5    0.999    16
#      5   34    27   -551.8    0.999     0
#      7   11    32   -551.3    0.992    10
# Total extinctions: 0
# Generation time: 1.304 sec (0.953 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: -810.44153 stdev: 1156.26415
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.951
# Mean genetic distance 2.600, standard deviation 0.644
# Population of 148 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   76    22   -549.5    0.962    22
#      2   76    25   -548.8    0.983    24
#      3   45    33   -553.1    0.784    16
#      4   40    17   -554.5    0.983    17
#      5   35    26   -551.7    0.999     0
#      7   12    25   -551.3    0.992    11
# Total extinctions: 0
# Generation time: 1.535 sec (1.042 average)
#
#  ****** Running generation 77 ******
#
# Population's average fitness: -769.60208 stdev: 981.80131
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.973
# Mean genetic distance 2.532, standard deviation 0.617
# Population of 150 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   77    23   -549.5    0.900    23
#      2   77    26   -548.8    0.992    25
#      3   46    35   -553.1    0.965    17
#      4   41    19   -554.5    0.999    18
#      5   36    27   -551.7    0.994     1
#      7   13    20   -551.3    0.991    12
# Total extinctions: 0
# Generation time: 1.451 sec (1.089 average)
#
#  ****** Running generation 78 ******
#
# Population's average fitness: -659.23452 stdev: 522.09753
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.981
# Mean genetic distance 2.612, standard deviation 0.675
# Population of 150 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   78    24   -549.5    0.928    24
#      2   78    25   -548.8    0.998    26
#      3   47    20   -551.3    0.974    18
#      4   42    25   -554.5    0.999    19
#      5   37    27   -551.7    0.987     2
#      7   14    17   -551.6    0.998    13
#      8    0    12       --       --     0
# Total extinctions: 0
# Generation time: 1.028 sec (1.126 average)
#
#  ****** Running generation 79 ******
#
# Population's average fitness: -777.61410 stdev: 988.96430
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
#
# Species 4 with 25 members is stagnated: removing it
# Average adjusted fitness: 0.954
# Mean genetic distance 2.591, standard deviation 0.792
# Population of 149 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   79    27   -549.5    0.977    25
#      2   79    27   -548.8    0.988    27
#      3   48    17   -551.3    0.968    19
#      5   38    28   -551.7    0.997     3
#      7   15    24   -551.6    0.973    14
#      8    1    26   -553.1    0.824     0
# Total extinctions: 0
# Generation time: 1.605 sec (1.203 average)
#
#  ****** Running generation 80 ******
#
# Population's average fitness: -710.06228 stdev: 721.09392
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
#
# Species 3 with 17 members is stagnated: removing it
# Average adjusted fitness: 0.978
# Mean genetic distance 2.578, standard deviation 0.789
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   80    30   -549.5    0.971    26
#      2   80    30   -548.8    0.992    28
#      5   39    31   -551.7    0.993     4
#      7   16    30   -551.6    0.993    15
#      8    2    29   -553.1    0.942     1
# Total extinctions: 0
# Generation time: 0.885 sec (1.224 average)
#
#  ****** Running generation 81 ******
#
# Population's average fitness: -632.54263 stdev: 254.37125
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.945
# Mean genetic distance 2.593, standard deviation 0.762
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   81    31   -549.5    0.953    27
#      2   81    31   -548.8    0.956    29
#      5   40    30   -551.7    0.928     5
#      7   17    29   -551.6    0.930    16
#      8    3    30   -553.1    0.961     2
# Total extinctions: 0
# Generation time: 0.917 sec (1.208 average)
#
#  ****** Running generation 82 ******
#
# Population's average fitness: -735.85737 stdev: 640.03399
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.968
# Mean genetic distance 2.604, standard deviation 0.725
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   82    33   -549.5    0.942    28
#      2   82    26   -548.8    0.989    30
#      5   41    31   -551.7    0.999     6
#      7   18    30   -551.6    0.985    17
#      8    4    30   -553.1    0.923     3
# Total extinctions: 0
# Generation time: 1.135 sec (1.239 average)
#
#  ****** Running generation 83 ******
#
# Population's average fitness: -756.25535 stdev: 788.30025
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.974
# Mean genetic distance 2.548, standard deviation 0.748
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   83    32   -549.5    0.971    29
#      2   83    27   -548.8    0.949    31
#      5   42    30   -551.7    0.978     7
#      7   19    31   -551.6    0.987    18
#      8    5    31   -553.1    0.987     4
# Total extinctions: 0
# Generation time: 2.172 sec (1.312 average)
#
#  ****** Running generation 84 ******
#
# Population's average fitness: -728.57357 stdev: 791.56691
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.978
# Mean genetic distance 2.540, standard deviation 0.737
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   84    32   -549.5    0.968    30
#      2   84    27   -548.8    0.957    32
#      5   43    31   -551.7    0.991     8
#      7   20    30   -551.6    0.995    19
#      8    6    30   -553.1    0.977     5
# Total extinctions: 0
# Generation time: 0.982 sec (1.302 average)
#
#  ****** Running generation 85 ******
#
# Population's average fitness: -744.28340 stdev: 700.47778
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.973
# Mean genetic distance 2.526, standard deviation 0.706
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   85    32   -549.5    0.949    31
#      2   85    28   -548.8    0.977    33
#      5   44    30   -551.7    0.984     9
#      7   21    31   -550.7    0.992     0
#      8    7    29   -553.1    0.965     6
# Total extinctions: 0
# Generation time: 0.949 sec (1.266 average)
#
#  ****** Running generation 86 ******
#
# Population's average fitness: -651.64435 stdev: 312.57835
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.941
# Mean genetic distance 2.545, standard deviation 0.715
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   86    32   -549.5    0.979    32
#      2   86    28   -548.8    0.936    34
#      5   45    30   -551.7    0.955    10
#      7   22    32   -550.7    0.976     1
#      8    8    29   -553.1    0.861     0
# Total extinctions: 0
# Generation time: 1.114 sec (1.224 average)
#
#  ****** Running generation 87 ******
#
# Population's average fitness: -736.59946 stdev: 749.46118
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.977
# Mean genetic distance 2.522, standard deviation 0.712
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   87    31   -549.5    0.983    33
#      2   87    29   -548.8    0.983    35
#      5   46    31   -551.7    0.994    11
#      7   23    31   -550.7    0.988     2
#      8    9    28   -553.1    0.937     1
# Total extinctions: 0
# Generation time: 0.999 sec (1.179 average)
#
#  ****** Running generation 88 ******
#
# Population's average fitness: -738.13082 stdev: 1019.42162
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.978
# Mean genetic distance 2.553, standard deviation 0.731
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   88    30   -549.5    0.947    34
#      2   88    30   -548.8    0.961    36
#      5   47    30   -551.7    0.997    12
#      7   24    30   -550.7    0.994     3
#      8   10    29   -553.1    0.990     0
# Total extinctions: 0
# Generation time: 1.811 sec (1.257 average)
#
#  ****** Running generation 89 ******
#
# Population's average fitness: -686.98912 stdev: 389.64543
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.923
# Mean genetic distance 2.551, standard deviation 0.730
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   89    31   -549.5    0.950    35
#      2   89    31   -548.8    0.956    37
#      5   48    29   -551.7    0.869    13
#      7   25    29   -550.7    0.914     4
#      8   11    30   -553.1    0.927     1
# Total extinctions: 0
# Generation time: 0.767 sec (1.173 average)
#
#  ****** Running generation 90 ******
#
# Population's average fitness: -663.30344 stdev: 316.72181
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.936
# Mean genetic distance 2.553, standard deviation 0.689
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   90    31   -549.5    0.924    36
#      2   90    31   -548.8    0.979    38
#      5   49    30   -551.7    0.980    14
#      7   26    30   -550.7    0.945     5
#      8   12    29   -553.1    0.854     2
# Total extinctions: 0
# Generation time: 0.838 sec (1.169 average)
#
#  ****** Running generation 91 ******
#
# Population's average fitness: -827.13639 stdev: 1084.60156
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.966
# Mean genetic distance 2.534, standard deviation 0.657
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   91    30   -549.5    0.939    37
#      2   91    30   -548.8    0.982    39
#      5   50    31   -551.7    0.993    15
#      7   27    31   -550.7    0.991     6
#      8   13    28   -553.1    0.926     3
# Total extinctions: 0
# Generation time: 1.336 sec (1.210 average)
#
#  ****** Running generation 92 ******
#
# Population's average fitness: -707.28192 stdev: 847.37661
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.982
# Mean genetic distance 2.517, standard deviation 0.685
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   92    29   -549.5    0.955    38
#      2   92    31   -548.8    0.998    40
#      5   51    30   -551.7    0.997    16
#      7   28    30   -550.7    0.988     7
#      8   14    29   -553.1    0.975     4
# Total extinctions: 0
# Generation time: 1.285 sec (1.225 average)
#
#  ****** Running generation 93 ******
#
# Population's average fitness: -659.59198 stdev: 315.10693
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.937
# Mean genetic distance 2.508, standard deviation 0.698
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   93    28   -549.5    0.859    39
#      2   93    32   -548.8    0.971    41
#      5   52    31   -551.7    0.973    17
#      7   29    29   -550.7    0.933     8
#      8   15    30   -553.1    0.951     5
# Total extinctions: 0
# Generation time: 0.854 sec (1.094 average)
#
#  ****** Running generation 94 ******
#
# Population's average fitness: -655.81470 stdev: 331.37289
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.939
# Mean genetic distance 2.593, standard deviation 0.693
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   94    29   -549.5    0.903    40
#      2   94    31   -548.8    0.973    42
#      5   53    30   -551.7    0.966    18
#      7   30    30   -550.7    0.926     9
#      8   16    29   -553.1    0.929     6
# Total extinctions: 0
# Generation time: 0.883 sec (1.084 average)
#
#  ****** Running generation 95 ******
#
# Population's average fitness: -674.43232 stdev: 363.90948
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.929
# Mean genetic distance 2.552, standard deviation 0.647
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   95    28   -549.5    0.894    41
#      2   95    32   -548.8    0.973    43
#      5   54    31   -551.7    0.988    19
#      7   31    31   -550.7    0.958    10
#      8   17    28   -553.1    0.831     7
# Total extinctions: 0
# Generation time: 1.583 sec (1.147 average)
#
#  ****** Running generation 96 ******
#
# Population's average fitness: -677.41026 stdev: 679.63029
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
#
# Species 5 with 31 members is stagnated: removing it
# Average adjusted fitness: 0.980
# Mean genetic distance 2.483, standard deviation 0.686
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   96    36   -549.5    0.955    42
#      2   96    39   -548.8    0.993    44
#      7   32    39   -550.7    0.995    11
#      8   18    37   -553.1    0.979     8
# Total extinctions: 0
# Generation time: 1.358 sec (1.172 average)
#
#  ****** Running generation 97 ******
#
# Population's average fitness: -731.51686 stdev: 418.20586
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.897
# Mean genetic distance 2.405, standard deviation 0.683
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   97    37   -549.5    0.896    43
#      2   97    40   -548.8    0.969    45
#      7   33    38   -550.7    0.923    12
#      8   19    35   -553.1    0.801     9
# Total extinctions: 0
# Generation time: 1.165 sec (1.188 average)
#
#  ****** Running generation 98 ******
#
# Population's average fitness: -719.96265 stdev: 718.04413
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.979
# Mean genetic distance 2.415, standard deviation 0.708
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   98    39   -549.5    0.982    44
#      2   98    37   -548.8    0.965    46
#      7   34    37   -550.7    0.985    13
#      8   20    36   -553.1    0.986    10
# Total extinctions: 0
# Generation time: 0.864 sec (1.093 average)
#
#  ****** Running generation 99 ******
#
# Population's average fitness: -674.22513 stdev: 385.85800
# Best fitness: -548.75729 - size: (4, 4) - species 2 - id 7617
# Average adjusted fitness: 0.929
# Mean genetic distance 2.412, standard deviation 0.684
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   99    38   -549.5    0.966    45
#      2   99    40   -548.8    0.989    47
#      7   35    39   -550.7    0.929    14
#      8   21    32   -553.1    0.833    11
# Total extinctions: 0
# Generation time: 0.740 sec (1.091 average)
# Test F1-score: 0.6027397260273972

# %%
# Сравнение моделей
print("\nСравнение моделей:")
print(f"F1-score на df_small: {result_small['f1_score']:.4f}")
print(f"F1-score на df_large: {result_large['f1_score']:.4f}")
if result_small['f1_score'] > result_large['f1_score']:
    print("Модель на df_small показала лучший результат.")
else:
    print("Модель на df_large показала лучший результат.")
# Out:
# Сравнение моделей:
# F1-score на df_small: 0.6667
# F1-score на df_large: 0.6027
# Модель на df_small показала лучший результат.

# %%
# Сохранение моделей и результатов
joblib.dump({
    'model': model_small,
    'winner': winner_small,
    'result': result_small,
    'scaler': scaler_small
}, '4_model_small.pkl')

joblib.dump({
    'model': model_large,
    'winner': winner_large,
    'result': result_large,
    'scaler': scaler_large
}, '4_model_large.pkl')
# Out:
# ['4_model_large.pkl']
