# %% [markdown]
# # Пример. EDA (исследовательский анализ данных)
# <font size=4>
# <b>Цель проекта:</b> обработка данных, анализ и определение факторов, влияющих на цену алмаза.</font>

# %% [markdown]
# # Инициализация проекта

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data= pd.read_csv('diamonds.csv')

# %% [markdown]
# # Исследование исходных данных

# %% [markdown]
# <font size=4>
# Датасет содержит следующие поля:
#
# - `price` — цена
# - `carat` — вес бриллианта
# - `cut` — качество огранки
# - `color` — цвет
# - `clarity` — чистота
# - `x` — длинна в мм по x
# - `y` — длинна в мм по y
# - `z` — длинна в мм по z
# - `depth` — общая глубина в процентах
# - `table` — ширина верхней части бриллианта относительно самой широкой точки
# </font>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
data.head(20)
# Out:
#     Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0            1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1            2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2            3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3            4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4            5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5            6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6            7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7            8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8            9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9           10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10          11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# 11          12   0.23      Ideal     J     VS1   62.8   56.0    340  3.93
# ...

# %% [markdown]
# <font size=4><b>Получили следующую характеристику исходных данных:</b>
#
# - Нет столбцов, где отсутствуют значения;
# - тип данных столбцов 'cut', 'color', 'clarity' нужно перевести в строковый;</font>

# %% [markdown]
# <font size=4>Столбцы с неподходящими типами данных:
#
# - изменение типа данных столбца 'carat', 'depth', 'table', 'x', 'y', 'z' с float на int;</font>

# %% [markdown]
# # Выводы и дальнейшие шаги

# %%
data.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %% [markdown]
# <b>Вывод:</b>
#
# - Вес и размеры алмаза влияют на цену алмаза.
#
# <b>Следующий шаг:</b>
#
# - Изменим неподходящие столбцы на int.

# %% [markdown]
# ## Коррекция типов данных

# %%
data['carat'] = (data['carat'] * 100).astype(int)
data['depth'] = (data['depth'] * 10).astype(int)
data['table'] = data['table'].astype(int)
data['x'] = (data['x']*100).astype(int)
data['y'] = (data['y']*100).astype(int)
data['z'] = (data['z']*100).astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  int64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  int64
#  6   table       53940 non-null  int64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  int64
#  9   y           53940 non-null  int64
#  10  z           53940 non-null  int64
# dtypes: int64(8), object(3)
# memory usage: 4.5+ MB

# %%
data['cut'].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
dict_cut = {
    'Ideal' : 4,
    'Premium' : 3,
    'Very Good' : 2,
    'Good' : 1,
    'Fair' : 0,
}
data['cut'] = data['cut'].map(dict_cut)

# %%
data['color'].value_counts()
# Out:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %%
dict_col = {
    'D' : 6,
    'H' : 5,
    'F' : 4,
    'E' : 3,
    'G' : 2,
    'I' : 1,
    'J' : 0,
}
data['color'] = data['color'].map(dict_col)

# %%
data['clarity'].value_counts()
# Out:
# clarity
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: count, dtype: int64

# %%
dict_clr = {
    'IF' : 7,
    'VVS1' : 6,
    'VVS2' : 5,
    'VS1' : 4,
    'VS2' : 3,
    'SI1' : 2,
    'SI2' : 1,
    'I1' : 0,
}
data['clarity'] = data['clarity'].map(dict_clr)

# %% [markdown]
# # **Проверка "очищенных" данных**

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  int64
#  2   cut         53940 non-null  int64
#  3   color       53940 non-null  int64
#  4   clarity     53940 non-null  int64
#  5   depth       53940 non-null  int64
#  6   table       53940 non-null  int64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  int64
#  9   y           53940 non-null  int64
#  10  z           53940 non-null  int64
# dtypes: int64(11)
# memory usage: 4.5 MB

# %%
data = data.drop('Unnamed: 0', axis=1)
data
# Out:
#        carat  cut  color  clarity  depth  table  price    x    y    z
# 0         23    4      3        1    615     55    326  395  398  243
# 1         21    3      3        2    598     61    326  389  384  231
# 2         23    1      3        4    569     65    327  405  407  231
# 3         28    3      1        3    624     58    334  420  423  263
# 4         31    1      0        1    633     58    335  434  434  275
# ...      ...  ...    ...      ...    ...    ...    ...  ...  ...  ...
# 53935     72    4      6        2    608     57   2757  575  576  350
# 53936     72    1      6        2    631     55   2757  569  575  361
# 53937     70    2      6        2    628     60   2757  566  568  356
# 53938     86    3      5        1    610     58   2757  615  612  374
# 53939     75    4      6        1    622     55   2757  583  587  364
#
# [53940 rows x 10 columns]

# %%
data.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean      79.749055      2.904097      3.295050      3.051020    617.494049
# std       47.361572      1.116600      1.707647      1.647136     14.326213
# min       20.000000      0.000000      0.000000      0.000000    430.000000
# 25%       40.000000      2.000000      2.000000      2.000000    610.000000
# 50%       70.000000      3.000000      3.000000      3.000000    618.000000
# 75%      104.000000      4.000000      5.000000      4.000000    625.000000
# max      501.000000      4.000000      6.000000      7.000000    790.000000
#
#               table         price             x             y             z
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean      57.448665   3932.799722    573.048183    573.386578    353.817649
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
numeric_columns = ['carat', 'depth', 'table', 'x', 'y', 'z']

min_max_scaler = MinMaxScaler()
data_minmax = data.copy()
data_minmax[numeric_columns] = min_max_scaler.fit_transform(data[numeric_columns])
print(data_minmax.head(10))
# Out:
#       carat  cut  color  clarity     depth     table  price         x  \
# 0  0.006237    4      3        1  0.513889  0.230769    326  0.367784
# 1  0.002079    3      3        2  0.466667  0.346154    326  0.362197
# 2  0.006237    1      3        4  0.386111  0.423077    327  0.377095
# 3  0.016632    3      1        3  0.538889  0.288462    334  0.391061
# 4  0.022869    1      0        1  0.563889  0.288462    335  0.404097
# 5  0.008316    2      0        5  0.550000  0.269231    336  0.366853
# 6  0.008316    2      1        6  0.536111  0.269231    336  0.367784
# 7  0.012474    2      5        2  0.525000  0.230769    337  0.378957
# 8  0.004158    0      3        3  0.613889  0.346154    337  0.360335
# 9  0.006237    2      5        4  0.455556  0.346154    338  0.372439
#
#           y         z
# 0  0.067572  0.076415
# 1  0.065195  0.072642
# 2  0.069100  0.072642
# 3  0.071817  0.082704
# 4  0.073684  0.086478
# 5  0.067233  0.077987
# 6  0.067572  0.077673
# ...

# %% [markdown]
# Цены варьируются от 326 до 18823, с медианой 2401. Это указывает на наличие как недорогих, так и аномально дорогих алмазов.
# Размеры, как и вес бриллиантов также варьируются, что влияет на их цену.
# cut, color, clarity - это категориальные переменные, закодированые численно

# %%
def analyzing(data, colomns):
    data_melted = data.melt(value_vars=colomns, var_name='Colomn', value_name='Value')

    plt.figure(figsize=(12, 9))
    sns.boxplot(x='Colomn', y='Value', data=data_melted)
    plt.grid(True)
    plt.show()
analyzing(data_minmax, colomns =['x', 'y', 'z'])

# %%
analyzing(data_minmax, 'price')

# %%
analyzing(data_minmax, colomns=['carat', 'table'])

# %%
analyzing(data_minmax, 'depth')

# %% [markdown]
# На основе boxplot, построенных для характеристик бриллиантов. Видно, что большинство значений сосредоточено в определённом диапазоне. Однако, есть выбросы, которые могут быть связаны с уникальными, аномальными или ошибочными экземплярами. Подкорректируем значения

# %%
def get_border_data(dataframe, colomn):
    Q1= dataframe[colomn].quantile(0.25)
    Q3 = dataframe[colomn].quantile(0.75) 

    IQR = Q3 - Q1 

    low_bound = Q1 - 1.25 * IQR
    up_bound = Q3 + 1.25 * IQR
    
    return [low_bound, up_bound]

# %%
def filtered(dataframe, args):
    filtered_df = dataframe.copy()
    for column in args:
        low_bound, up_bound = get_border_data(filtered_df, column)
                
        filtered_df = filtered_df[
            (filtered_df[column] >= low_bound) & 
            (filtered_df[column] <= up_bound)]
    
    return filtered_df

# %% [markdown]
# Реализована функция для фильтрации выбросов в данных на основе межквартильного размаха (IQR). Это позволяет удалить аномальные значения, которые могут искажать результаты анализа.

# %%
filteredata = filtered(data_minmax, args= ['x','y','z','table','carat','depth','price'])

# %%
filteredata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43910 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    43910 non-null  float64
#  1   cut      43910 non-null  int64
#  2   color    43910 non-null  int64
#  3   clarity  43910 non-null  int64
#  4   depth    43910 non-null  float64
#  5   table    43910 non-null  float64
#  6   price    43910 non-null  int64
#  7   x        43910 non-null  float64
#  8   y        43910 non-null  float64
#  9   z        43910 non-null  float64
# dtypes: float64(6), int64(4)
# memory usage: 3.7 MB

# %%
filteredata.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# Эти гистограммы позволяют визуализировать распределение различных характеристик бриллиантов. Чтобы мы могли понимать в каком диапазоне работаем

# %%
filteredata['v'] = filteredata['x'] * filteredata['y'] * filteredata['z']

# %%
sns.histplot(filteredata['v'], bins=30, kde=True)
plt.title('Распределение объема бриллианта')
plt.show()

# %% [markdown]
# Был добавлен новый столбец v, который представляет собой объем бриллианта, рассчитанный как произведение длин по осям x, y и z. Это позволяет удобнее оценить кореляцию размерности каждого бриллианта в датасете.
#
# Гистограмма с ядерной оценкой плотности (KDE) показывает, что большинство объемов сосредоточено в диапазоне от 0.5 до 2.5, что указывает на то, что большинство бриллиантов имеют относительно небольшие объемы.

# %%
print (data.hist('price', bins=100))
print (filteredata.hist('price', bins=100))
# Out:
# [[<Axes: title={'center': 'price'}>]]
# [[<Axes: title={'center': 'price'}>]]

# %% [markdown]
# На первой гистограмме видно, что распределение цен до фильтрации имеет длинный хвост в сторону более высоких цен. Бриллиантов с очень высокой ценой могут искажать общую картину.
#
# На второй гистограмме, после фильтрации выбросов, распределение цен становится более компактным. Большинство цен сосредоточено в диапазоне до 10,000 единиц, что делает данные более репрезентативными для анализа.

# %%
sns.lmplot(x='v', y='price', data=filteredata)

# %% [markdown]
# График lmplot показывает линейную зависимость между объемом бриллианта (v) и его ценой (price). Это позволяет визуализировать, как увеличение объема влияет на стоимость бриллианта.
#
# Виден положительный тренд, указывающий на то, что с увеличением объема бриллианта его цена также увеличивается. Это ожидаемо, так как более крупные бриллианты обычно стоят дороже.
#
# Несмотря на общий тренд, наблюдается значительный разброс данных. Это может быть связано с влиянием других факторов, таких как качество огранки, цвет, чистота и вес, которые могут также влиять на цену.

# %%
sns.lmplot(x='v', y='carat', data=filteredata)

# %% [markdown]
# Определив линейную зависимость между объемом бриллианта и его весом, поможет нам с пониманием в анализе, так как вес является одним из ключевых факторов, влияющих на цену.

# %%
filteredata.boxplot(by ='clarity', column =['price'],figsize=(7,4), grid = True)
filteredata.boxplot(by ='cut', column =['price'],figsize=(7,4), grid = True)
filteredata.boxplot(by ='color', column =['price'],figsize=(7,4), grid = True)
# Out:
# <Axes: title={'center': 'price'}, xlabel='color'>

# %% [markdown]
# Boxplot'ы позволяют визуализировать распределение цен в зависимости от различных характеристик бриллиантов
#
# Boxplot, сгруппированный по первым трём, показывает, как цена варьируется в зависимости от уровня чистоты бриллианта. Ожидается, что бриллианты с более высокой чистотой будут иметь более высокую цену.
#
# Boxplot, сгруппированный по ширине, показывает, как цена зависит от ширины верхней части бриллианта. Оптимальные значения ширины могут быть связаны с более высокой ценой.
#
# Общие наблюдения:
#
# На всех графиках видно, что цена варьируется в зависимости от характеристик, но это не ярко выражено возможно в недостаточности количестве данных, также присутствуют выбросы.

# %%
plt.figure(figsize=(10, 8))
corr_matrix = filteredata.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.pairplot(data[['carat', 'price', 'x']])
plt.show()

# %% [markdown]
# Это покажет все парные зависимости и распределения

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['carat'], data['price'], alpha=0.5)
plt.xlabel('Carat')
plt.ylabel('Price')
plt.title('Зависимость веса и цены')
plt.show()

# %% [markdown]
# Изучение диаграммы рассеивания, если есть выбросы (например, очень высокая цена при маленьком carat), они будут видны.

# %% [markdown]
# # **Заключение**:

# %% [markdown]
# Основными факторами, влияющими на цену бриллиантов, являются вес и размеры. Эти параметры имеют сильную положительную корреляцию с ценой.
#
# Качество огранки, цвет и чистота, хотя и важны для оценки бриллиантов, имеют меньшее прямое влияние на цену в данном датасете.
#
# Фильтрация выбросов и визуализация данных позволили более четко увидеть основные тенденции и взаимосвязи между характеристиками бриллиантов.

# %%
filteredata.to_csv('1dataset.csv', header=True, index = False)
